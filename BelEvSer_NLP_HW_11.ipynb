# %% [markdown]
# <a href="https://colab.research.google.com/github/geekevgin/-Python/blob/main/BelEvSer_NLP_HW_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
import transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 45.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
import transformers
import tensorflow_datasets as tfds
import tensorflow as tf
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
examples, metadata = tfds.load('ted_hrlr_translate/ru_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/208106 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompletePUMWB3/ted_hrlr_translate-trai…
# Generating validation examples...:   0%|          | 0/4805 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompletePUMWB3/ted_hrlr_translate-vali…
# Generating test examples...:   0%|          | 0/5476 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompletePUMWB3/ted_hrlr_translate-test…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0. Subsequent calls will reuse this data.

# %%
tokenizer_en = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (en.numpy() for ru, en in train_examples), target_vocab_size=2**13)

tokenizer_ru = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (ru.numpy() for ru, en in train_examples), target_vocab_size=2**13)

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64
MAX_LENGTH = 40

# %%
def encode(lang1, lang2):
  lang1 = [tokenizer_ru.vocab_size] + tokenizer_ru.encode(
      lang1.numpy()) + [tokenizer_ru.vocab_size+1]

  lang2 = [tokenizer_en.vocab_size] + tokenizer_en.encode(
      lang2.numpy()) + [tokenizer_en.vocab_size+1]
  
  return lang1, lang2

# %%
def tf_encode(ru, en):

# tf.pyfunction method is used to call a custom function (encode) with two arguments (ru and en). 
# The two arguments are then mapped to two data types (tf.int64, tf.int64) which will be returned as a tuple containing two Tensors.
  result_ru, result_en = tf.py_function(encode, [ru, en], [tf.int64, tf.int64])

#set_shape method is used to set the shape of each Tensor to [None], which means that it will be able to accept variable-length inputs.
  result_ru.set_shape([None]) 
  result_en.set_shape([None])

  return result_ru, result_en

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
  return tf.logical_and(tf.size(x) <= max_length,
                        tf.size(y) <= max_length)

# %%
train_dataset = train_examples.map(tf_encode)
train_dataset = train_dataset.filter(filter_max_length)
train_dataset = train_dataset.cache()
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
val_dataset = val_examples.map(tf_encode)
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE) # create batches of data in which the examples are padded with zeros to match the maximum length.

# %%
pt_batch, en_batch = next(iter(val_dataset))
pt_batch, en_batch
# Out:
# (<tf.Tensor: shape=(64, 38), dtype=int64, numpy=
#  array([[8179,   57,   86, ...,    0,    0,    0],
#         [8179,    3,   38, ...,    0,    0,    0],
#         [8179,   57,  135, ...,    0,    0,    0],
#         ...,
#         [8179,    3,    7, ...,    0,    0,    0],
#         [8179,  138,  250, ...,    0,    0,    0],
#         [8179,   19,    7, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 40), dtype=int64, numpy=
#  array([[8245,   90,  101, ...,    0,    0,    0],
#         [8245,   70,   25, ...,    0,    0,    0],
#         [8245,   90,  153, ...,    0,    0,    0],
#         ...,
#         [8245,    4,   18, ...,    0,    0,    0],
#         [8245,   19,   59, ...,    0,    0,    0],
#         [8245,   24,   18, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  print(pos * angle_rates)
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis], # стобец
                          np.arange(d_model)[np.newaxis, :], # строка
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
pos_encoding = positional_encoding(50, 512)
print (pos_encoding.shape)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00000000e+00 9.64661620e-01 ... 1.07460783e-04
#   1.03663293e-04 1.03663293e-04]
#  [2.00000000e+00 2.00000000e+00 1.92932324e+00 ... 2.14921566e-04
#   2.07326586e-04 2.07326586e-04]
#  ...
#  [4.70000000e+01 4.70000000e+01 4.53390961e+01 ... 5.05065679e-03
#   4.87217476e-03 4.87217476e-03]
#  [4.80000000e+01 4.80000000e+01 4.63037578e+01 ... 5.15811758e-03
#   4.97583806e-03 4.97583806e-03]
#  [4.90000000e+01 4.90000000e+01 4.72684194e+01 ... 5.26557836e-03
#   5.07950135e-03 5.07950135e-03]]
# (1, 50, 512)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32) # 1 if element is null, otherwise - 0
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0) # Copy a tensor setting everything outside a central band in each innermost matrix to zero.
  return mask  # (seq_len, seq_len)

# %%
x = tf.random.uniform((1, 3))
print(x)
temp = create_look_ahead_mask(x.shape[1])
temp
# Out:
# tf.Tensor([[0.73165154 0.7845074  0.6839001 ]], shape=(1, 3), dtype=float32)
# <tf.Tensor: shape=(3, 3), dtype=float32, numpy=
# array([[0., 1., 1.],
#        [0., 0., 1.],
#        [0., 0., 0.]], dtype=float32)>

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
def print_out(q, k, v):
  temp_out, temp_attn = scaled_dot_product_attention(
      q, k, v, None)
  print ('Attention weights are:')
  print (temp_attn)
  print ('Output is:')
  print (temp_out)

# %%
np.set_printoptions(suppress=True)
temp_k = tf.constant([[10,0,0],
                      [0,10,0],
                      [0,0,10],
                      [0,0,10]], dtype=tf.float32)  # (4, 3)

temp_v = tf.constant([[   1,0],
                      [  10,0],
                      [ 100,5],
                      [1000,6]], dtype=tf.float32)  # (4, 2)

temp_q = tf.constant([[0, 10, 0]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor([[0. 1. 0. 0.]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[10.  0.]], shape=(1, 2), dtype=float32)

# %%
temp_q = tf.constant([[0, 0, 10]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor([[0.  0.  0.5 0.5]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[550.    5.5]], shape=(1, 2), dtype=float32)

# %%
temp_q = tf.constant([[10, 10, 0]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor([[0.5 0.5 0.  0. ]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[5.5 0. ]], shape=(1, 2), dtype=float32)

# %%
temp_q = tf.constant([[0, 0, 10], [0, 10, 0], [10, 10, 10]], dtype=tf.float32)  # (3, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor(
# [[0.   0.   0.5  0.5 ]
#  [0.   1.   0.   0.  ]
#  [0.25 0.25 0.25 0.25]], shape=(3, 4), dtype=float32)
# Output is:
# tf.Tensor(
# [[550.     5.5 ]
#  [ 10.     0.  ]
#  [277.75   2.75]], shape=(3, 2), dtype=float32)

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    # If one component of shape is the special value -1, the size of that dimension is computed so that 
    # the total size remains constant. In particular, a shape of [-1] flattens into 1-D. 
    # At most one component of shape can be -1.
    
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %%
temp_mha = MultiHeadAttention(d_model=10, num_heads=2)
y = tf.random.uniform((2, 3, 10))  # (batch_size, encoder_sequence, d_model)
out, attn = temp_mha(y, k=y, q=y, mask=None)
print('Выходные размерности:  \n')
out.shape, attn.shape
# Out:
# Выходные размерности:
# (TensorShape([2, 3, 10]), TensorShape([2, 2, 3, 3]))

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
sample_ffn = point_wise_feed_forward_network(512, 2048)
sample_ffn(tf.random.uniform((64, 50, 512))).shape
# Out:
# TensorShape([64, 50, 512])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
sample_encoder_layer = EncoderLayer(512, 8, 2048)

sample_encoder_layer_output = sample_encoder_layer(
    tf.random.uniform((64, 43, 512)), False, None)

sample_encoder_layer_output.shape  # (batch_size, input_seq_len, d_model)
# Out:
# TensorShape([64, 43, 512])

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

# %%
sample_decoder_layer = DecoderLayer(512, 8, 2048)

sample_decoder_layer_output, _, _ = sample_decoder_layer(
    tf.random.uniform((64, 50, 512)), sample_encoder_layer_output, 
    False, None, None)

sample_decoder_layer_output.shape  # (batch_size, target_seq_len, d_model)
# Out:
# TensorShape([64, 50, 512])

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1] #40
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
sample_encoder = Encoder(num_layers=2, d_model=512, num_heads=8, 
                         dff=2048, input_vocab_size=8500,
                         maximum_position_encoding=10000)
temp_input = tf.random.uniform((64, 62), dtype=tf.int64, minval=0, maxval=200)

sample_encoder_output = sample_encoder(temp_input, training=False, mask=None)

print (sample_encoder_output.shape)  # (batch_size, input_seq_len, d_model)
# Out:
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.96466162 ...    0.00010746
#      0.00010366    0.00010366]
#  [   2.            2.            1.92932324 ...    0.00021492
#      0.00020733    0.00020733]
#  ...
#  [9997.         9997.         9643.72221425 ...    1.07428545
#      1.03632194    1.03632194]
#  [9998.         9998.         9644.68687587 ...    1.07439291
#      1.0364256     1.0364256 ]
#  [9999.         9999.         9645.65153749 ...    1.07450037
#      1.03652927    1.03652927]]
# (64, 62, 512)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
sample_decoder = Decoder(num_layers=2, d_model=512, num_heads=8, 
                         dff=2048, target_vocab_size=8000,
                         maximum_position_encoding=5000)
temp_input = tf.random.uniform((64, 26), dtype=tf.int64, minval=0, maxval=200)

output, attn = sample_decoder(temp_input, 
                              enc_output=sample_encoder_output, 
                              training=False,
                              look_ahead_mask=None, 
                              padding_mask=None)

output.shape, attn['decoder_layer2_block2'].shape
# Out:
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.96466162 ...    0.00010746
#      0.00010366    0.00010366]
#  [   2.            2.            1.92932324 ...    0.00021492
#      0.00020733    0.00020733]
#  ...
#  [4997.         4997.         4820.4141147  ...    0.53698153
#      0.51800547    0.51800547]
#  [4998.         4998.         4821.37877632 ...    0.53708899
#      0.51810914    0.51810914]
#  [4999.         4999.         4822.34343794 ...    0.53719645
#      0.5182128     0.5182128 ]]
# (TensorShape([64, 26, 512]), TensorShape([64, 8, 26, 62]))

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, 
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff, 
                           input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training, enc_padding_mask, 
           look_ahead_mask, dec_padding_mask):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
sample_transformer = Transformer(
    num_layers=2, d_model=512, num_heads=8, dff=2048, 
    input_vocab_size=8500, target_vocab_size=8000, 
    pe_input=10000, pe_target=6000)

temp_input = tf.random.uniform((64, 38), dtype=tf.int64, minval=0, maxval=200)
temp_target = tf.random.uniform((64, 36), dtype=tf.int64, minval=0, maxval=200)

fn_out, _ = sample_transformer(temp_input, temp_target, training=False, 
                               enc_padding_mask=None, 
                               look_ahead_mask=None,
                               dec_padding_mask=None)

fn_out.shape  # (batch_size, tar_seq_len, target_vocab_size)
# Out:
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.96466162 ...    0.00010746
#      0.00010366    0.00010366]
#  [   2.            2.            1.92932324 ...    0.00021492
#      0.00020733    0.00020733]
#  ...
#  [9997.         9997.         9643.72221425 ...    1.07428545
#      1.03632194    1.03632194]
#  [9998.         9998.         9644.68687587 ...    1.07439291
#      1.0364256     1.0364256 ]
#  [9999.         9999.         9645.65153749 ...    1.07450037
#      1.03652927    1.03652927]]
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.96466162 ...    0.00010746
#      0.00010366    0.00010366]
#  [   2.            2.            1.92932324 ...    0.00021492
#      0.00020733    0.00020733]
#  ...
#  [5997.         5997.         5785.07573461 ...    0.64444231
#      0.62166877    0.62166877]
#  [5998.         5998.         5786.04039623 ...    0.64454978
#      0.62177243    0.62177243]
#  [5999.         5999.         5787.00505785 ...    0.64465724
#      0.62187609    0.62187609]]
# TensorShape([64, 36, 8000])

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

input_vocab_size = tokenizer_ru.vocab_size + 2
target_vocab_size = tokenizer_en.vocab_size + 2
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    step = tf.cast(step, np.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))
  
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size, 
                          pe_input=input_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)
# Out:
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.86596432 ...    0.00013335
#      0.00011548    0.00011548]
#  [   2.            2.            1.73192865 ...    0.0002667
#      0.00023096    0.00023096]
#  ...
#  [8178.         8178.         7081.85623644 ...    1.09055383
#      0.94438071    0.94438071]
#  [8179.         8179.         7082.72220076 ...    1.09068718
#      0.94449619    0.94449619]
#  [8180.         8180.         7083.58816509 ...    1.09082053
#      0.94461166    0.94461166]]
# [[   0.            0.            0.         ...    0.
#      0.            0.        ]
#  [   1.            1.            0.86596432 ...    0.00013335
#      0.00011548    0.00011548]
#  [   2.            2.            1.73192865 ...    0.0002667
#      0.00023096    0.00023096]
#  ...
#  [8244.         8244.         7139.00988178 ...    1.09935507
#      0.95200227    0.95200227]
#  [8245.         8245.         7139.8758461  ...    1.09948842
#      0.95211775    0.95211775]
#  [8246.         8246.         7140.74181043 ...    1.09962177
#      0.95223322    0.95223322]]

# %%
def create_masks(inp, tar):
  # Encoder padding mask
  enc_padding_mask = create_padding_mask(inp)
  
  # Used in the 2nd attention block in the decoder.
  # This padding mask is used to mask the encoder outputs.
  dec_padding_mask = create_padding_mask(inp)
  
  # Used in the 1st attention block in the decoder.
  # It is used to pad and mask future tokens in the input received by 
  # the decoder.
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  
  return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %%
EPOCHS = 30

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp, 
                                 True, 
                                 enc_padding_mask, 
                                 combined_mask, 
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_dataset):
    train_step(inp, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                         ckpt_save_path))
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 9.0028 Accuracy 0.0009
# Epoch 1 Batch 50 Loss 8.9580 Accuracy 0.0038
# Epoch 1 Batch 100 Loss 8.8736 Accuracy 0.0256
# Epoch 1 Batch 150 Loss 8.7721 Accuracy 0.0330
# Epoch 1 Batch 200 Loss 8.6429 Accuracy 0.0369
# Epoch 1 Batch 250 Loss 8.4852 Accuracy 0.0450
# Epoch 1 Batch 300 Loss 8.3084 Accuracy 0.0543
# Epoch 1 Batch 350 Loss 8.1223 Accuracy 0.0614
# Epoch 1 Batch 400 Loss 7.9404 Accuracy 0.0675
# Epoch 1 Batch 450 Loss 7.7765 Accuracy 0.0734
# Epoch 1 Batch 500 Loss 7.6306 Accuracy 0.0795
# Epoch 1 Batch 550 Loss 7.4960 Accuracy 0.0870
# Epoch 1 Batch 600 Loss 7.3673 Accuracy 0.0946
# Epoch 1 Batch 650 Loss 7.2441 Accuracy 0.1021
# Epoch 1 Batch 700 Loss 7.1288 Accuracy 0.1091
# Epoch 1 Batch 750 Loss 7.0213 Accuracy 0.1159
# Epoch 1 Batch 800 Loss 6.9199 Accuracy 0.1226
# Epoch 1 Batch 850 Loss 6.8243 Accuracy 0.1290
# Epoch 1 Batch 900 Loss 6.7346 Accuracy 0.1352
# Epoch 1 Batch 950 Loss 6.6498 Accuracy 0.1411
# Epoch 1 Batch 1000 Loss 6.5707 Accuracy 0.1467
# Epoch 1 Batch 1050 Loss 6.4966 Accuracy 0.1519
# Epoch 1 Batch 1100 Loss 6.4276 Accuracy 0.1570
# Epoch 1 Batch 1150 Loss 6.3620 Accuracy 0.1618
# Epoch 1 Batch 1200 Loss 6.2995 Accuracy 0.1665
# Epoch 1 Batch 1250 Loss 6.2411 Accuracy 0.1709
# Epoch 1 Batch 1300 Loss 6.1852 Accuracy 0.1751
# Epoch 1 Batch 1350 Loss 6.1327 Accuracy 0.1791
# Epoch 1 Batch 1400 Loss 6.0839 Accuracy 0.1827
# Epoch 1 Batch 1450 Loss 6.0375 Accuracy 0.1862
# Epoch 1 Batch 1500 Loss 5.9931 Accuracy 0.1896
# Epoch 1 Batch 1550 Loss 5.9514 Accuracy 0.1926
# Epoch 1 Batch 1600 Loss 5.9109 Accuracy 0.1957
# Epoch 1 Batch 1650 Loss 5.8717 Accuracy 0.1987
# Epoch 1 Batch 1700 Loss 5.8352 Accuracy 0.2015
# Epoch 1 Batch 1750 Loss 5.8000 Accuracy 0.2042
# Epoch 1 Batch 1800 Loss 5.7656 Accuracy 0.2069
# Epoch 1 Batch 1850 Loss 5.7327 Accuracy 0.2095
# Epoch 1 Batch 1900 Loss 5.7015 Accuracy 0.2119
# Epoch 1 Batch 1950 Loss 5.6710 Accuracy 0.2143
# Epoch 1 Batch 2000 Loss 5.6419 Accuracy 0.2165
# Epoch 1 Batch 2050 Loss 5.6140 Accuracy 0.2187
# Epoch 1 Batch 2100 Loss 5.5864 Accuracy 0.2208
# Epoch 1 Batch 2150 Loss 5.5591 Accuracy 0.2230
# Epoch 1 Batch 2200 Loss 5.5340 Accuracy 0.2249
# Epoch 1 Batch 2250 Loss 5.5094 Accuracy 0.2268
# Epoch 1 Batch 2300 Loss 5.4853 Accuracy 0.2286
# Epoch 1 Batch 2350 Loss 5.4621 Accuracy 0.2305
# Epoch 1 Batch 2400 Loss 5.4382 Accuracy 0.2324
# Epoch 1 Batch 2450 Loss 5.4154 Accuracy 0.2342
# Epoch 1 Batch 2500 Loss 5.3926 Accuracy 0.2360
# Epoch 1 Batch 2550 Loss 5.3712 Accuracy 0.2377
# Epoch 1 Batch 2600 Loss 5.3499 Accuracy 0.2394
# Epoch 1 Loss 5.3402 Accuracy 0.2402
# Time taken for 1 epoch: 529.3487379550934 secs
#
# Epoch 2 Batch 0 Loss 4.1736 Accuracy 0.3381
# Epoch 2 Batch 50 Loss 4.2299 Accuracy 0.3265
# Epoch 2 Batch 100 Loss 4.2306 Accuracy 0.3282
# Epoch 2 Batch 150 Loss 4.2165 Accuracy 0.3295
# Epoch 2 Batch 200 Loss 4.2085 Accuracy 0.3310
# Epoch 2 Batch 250 Loss 4.2000 Accuracy 0.3321
# Epoch 2 Batch 300 Loss 4.1901 Accuracy 0.3333
# Epoch 2 Batch 350 Loss 4.1794 Accuracy 0.3346
# Epoch 2 Batch 400 Loss 4.1751 Accuracy 0.3347
# Epoch 2 Batch 450 Loss 4.1635 Accuracy 0.3360
# Epoch 2 Batch 500 Loss 4.1546 Accuracy 0.3369
# Epoch 2 Batch 550 Loss 4.1452 Accuracy 0.3380
# Epoch 2 Batch 600 Loss 4.1354 Accuracy 0.3390
# Epoch 2 Batch 650 Loss 4.1251 Accuracy 0.3400
# Epoch 2 Batch 700 Loss 4.1166 Accuracy 0.3410
# Epoch 2 Batch 750 Loss 4.1087 Accuracy 0.3419
# Epoch 2 Batch 800 Loss 4.1008 Accuracy 0.3427
# Epoch 2 Batch 850 Loss 4.0938 Accuracy 0.3435
# Epoch 2 Batch 900 Loss 4.0845 Accuracy 0.3445
# Epoch 2 Batch 950 Loss 4.0761 Accuracy 0.3454
# Epoch 2 Batch 1000 Loss 4.0673 Accuracy 0.3463
# Epoch 2 Batch 1050 Loss 4.0586 Accuracy 0.3473
# Epoch 2 Batch 1100 Loss 4.0511 Accuracy 0.3481
# Epoch 2 Batch 1150 Loss 4.0438 Accuracy 0.3487
# Epoch 2 Batch 1200 Loss 4.0362 Accuracy 0.3495
# Epoch 2 Batch 1250 Loss 4.0291 Accuracy 0.3503
# Epoch 2 Batch 1300 Loss 4.0209 Accuracy 0.3511
# Epoch 2 Batch 1350 Loss 4.0134 Accuracy 0.3519
# Epoch 2 Batch 1400 Loss 4.0058 Accuracy 0.3527
# Epoch 2 Batch 1450 Loss 3.9979 Accuracy 0.3536
# Epoch 2 Batch 1500 Loss 3.9894 Accuracy 0.3545
# Epoch 2 Batch 1550 Loss 3.9808 Accuracy 0.3554
# Epoch 2 Batch 1600 Loss 3.9727 Accuracy 0.3563
# Epoch 2 Batch 1650 Loss 3.9652 Accuracy 0.3572
# Epoch 2 Batch 1700 Loss 3.9577 Accuracy 0.3580
# Epoch 2 Batch 1750 Loss 3.9497 Accuracy 0.3589
# Epoch 2 Batch 1800 Loss 3.9430 Accuracy 0.3597
# Epoch 2 Batch 1850 Loss 3.9352 Accuracy 0.3605
# Epoch 2 Batch 1900 Loss 3.9277 Accuracy 0.3613
# Epoch 2 Batch 1950 Loss 3.9207 Accuracy 0.3620
# Epoch 2 Batch 2000 Loss 3.9129 Accuracy 0.3628
# Epoch 2 Batch 2050 Loss 3.9046 Accuracy 0.3637
# Epoch 2 Batch 2100 Loss 3.8967 Accuracy 0.3646
# Epoch 2 Batch 2150 Loss 3.8893 Accuracy 0.3653
# Epoch 2 Batch 2200 Loss 3.8818 Accuracy 0.3661
# Epoch 2 Batch 2250 Loss 3.8745 Accuracy 0.3669
# Epoch 2 Batch 2300 Loss 3.8673 Accuracy 0.3676
# Epoch 2 Batch 2350 Loss 3.8597 Accuracy 0.3684
# Epoch 2 Batch 2400 Loss 3.8524 Accuracy 0.3691
# Epoch 2 Batch 2450 Loss 3.8447 Accuracy 0.3699
# Epoch 2 Batch 2500 Loss 3.8374 Accuracy 0.3707
# Epoch 2 Batch 2550 Loss 3.8300 Accuracy 0.3714
# Epoch 2 Batch 2600 Loss 3.8228 Accuracy 0.3722
# Epoch 2 Loss 3.8192 Accuracy 0.3726
# Time taken for 1 epoch: 189.3333649635315 secs
#
# Epoch 3 Batch 0 Loss 3.4912 Accuracy 0.4016
# Epoch 3 Batch 50 Loss 3.4240 Accuracy 0.4140
# Epoch 3 Batch 100 Loss 3.3988 Accuracy 0.4164
# Epoch 3 Batch 150 Loss 3.3931 Accuracy 0.4175
# Epoch 3 Batch 200 Loss 3.3896 Accuracy 0.4177
# Epoch 3 Batch 250 Loss 3.3838 Accuracy 0.4181
# Epoch 3 Batch 300 Loss 3.3817 Accuracy 0.4186
# Epoch 3 Batch 350 Loss 3.3724 Accuracy 0.4194
# Epoch 3 Batch 400 Loss 3.3675 Accuracy 0.4198
# Epoch 3 Batch 450 Loss 3.3591 Accuracy 0.4205
# Epoch 3 Batch 500 Loss 3.3538 Accuracy 0.4212
# Epoch 3 Batch 550 Loss 3.3503 Accuracy 0.4218
# Epoch 3 Batch 600 Loss 3.3442 Accuracy 0.4225
# Epoch 3 Batch 650 Loss 3.3364 Accuracy 0.4234
# Epoch 3 Batch 700 Loss 3.3308 Accuracy 0.4240
# Epoch 3 Batch 750 Loss 3.3245 Accuracy 0.4248
# Epoch 3 Batch 800 Loss 3.3184 Accuracy 0.4254
# Epoch 3 Batch 850 Loss 3.3120 Accuracy 0.4262
# Epoch 3 Batch 900 Loss 3.3057 Accuracy 0.4269
# Epoch 3 Batch 950 Loss 3.3006 Accuracy 0.4275
# Epoch 3 Batch 1000 Loss 3.2958 Accuracy 0.4281
# Epoch 3 Batch 1050 Loss 3.2911 Accuracy 0.4287
# Epoch 3 Batch 1100 Loss 3.2868 Accuracy 0.4291
# Epoch 3 Batch 1150 Loss 3.2806 Accuracy 0.4299
# Epoch 3 Batch 1200 Loss 3.2758 Accuracy 0.4304
# Epoch 3 Batch 1250 Loss 3.2696 Accuracy 0.4311
# Epoch 3 Batch 1300 Loss 3.2640 Accuracy 0.4319
# Epoch 3 Batch 1350 Loss 3.2589 Accuracy 0.4324
# Epoch 3 Batch 1400 Loss 3.2541 Accuracy 0.4330
# Epoch 3 Batch 1450 Loss 3.2504 Accuracy 0.4334
# Epoch 3 Batch 1500 Loss 3.2449 Accuracy 0.4341
# Epoch 3 Batch 1550 Loss 3.2391 Accuracy 0.4348
# Epoch 3 Batch 1600 Loss 3.2340 Accuracy 0.4354
# Epoch 3 Batch 1650 Loss 3.2302 Accuracy 0.4358
# Epoch 3 Batch 1700 Loss 3.2256 Accuracy 0.4363
# Epoch 3 Batch 1750 Loss 3.2208 Accuracy 0.4368
# Epoch 3 Batch 1800 Loss 3.2156 Accuracy 0.4373
# Epoch 3 Batch 1850 Loss 3.2119 Accuracy 0.4378
# Epoch 3 Batch 1900 Loss 3.2072 Accuracy 0.4383
# Epoch 3 Batch 1950 Loss 3.2033 Accuracy 0.4387
# Epoch 3 Batch 2000 Loss 3.1985 Accuracy 0.4392
# Epoch 3 Batch 2050 Loss 3.1939 Accuracy 0.4397
# Epoch 3 Batch 2100 Loss 3.1895 Accuracy 0.4402
# Epoch 3 Batch 2150 Loss 3.1848 Accuracy 0.4407
# Epoch 3 Batch 2200 Loss 3.1800 Accuracy 0.4412
# Epoch 3 Batch 2250 Loss 3.1754 Accuracy 0.4418
# Epoch 3 Batch 2300 Loss 3.1715 Accuracy 0.4422
# Epoch 3 Batch 2350 Loss 3.1675 Accuracy 0.4426
# Epoch 3 Batch 2400 Loss 3.1639 Accuracy 0.4431
# Epoch 3 Batch 2450 Loss 3.1593 Accuracy 0.4435
# Epoch 3 Batch 2500 Loss 3.1554 Accuracy 0.4440
# Epoch 3 Batch 2550 Loss 3.1520 Accuracy 0.4444
# Epoch 3 Batch 2600 Loss 3.1484 Accuracy 0.4448
# Epoch 3 Loss 3.1464 Accuracy 0.4450
# Time taken for 1 epoch: 184.47337412834167 secs
#
# Epoch 4 Batch 0 Loss 3.0400 Accuracy 0.4578
# Epoch 4 Batch 50 Loss 2.9114 Accuracy 0.4701
# Epoch 4 Batch 100 Loss 2.9027 Accuracy 0.4724
# Epoch 4 Batch 150 Loss 2.9022 Accuracy 0.4720
# Epoch 4 Batch 200 Loss 2.9116 Accuracy 0.4703
# Epoch 4 Batch 250 Loss 2.9079 Accuracy 0.4708
# Epoch 4 Batch 300 Loss 2.9062 Accuracy 0.4710
# Epoch 4 Batch 350 Loss 2.9004 Accuracy 0.4719
# Epoch 4 Batch 400 Loss 2.8977 Accuracy 0.4723
# Epoch 4 Batch 450 Loss 2.8923 Accuracy 0.4728
# Epoch 4 Batch 500 Loss 2.8906 Accuracy 0.4731
# Epoch 4 Batch 550 Loss 2.8852 Accuracy 0.4738
# Epoch 4 Batch 600 Loss 2.8838 Accuracy 0.4740
# Epoch 4 Batch 650 Loss 2.8819 Accuracy 0.4744
# Epoch 4 Batch 700 Loss 2.8772 Accuracy 0.4748
# Epoch 4 Batch 750 Loss 2.8733 Accuracy 0.4753
# Epoch 4 Batch 800 Loss 2.8706 Accuracy 0.4758
# Epoch 4 Batch 850 Loss 2.8669 Accuracy 0.4762
# Epoch 4 Batch 900 Loss 2.8658 Accuracy 0.4763
# Epoch 4 Batch 950 Loss 2.8637 Accuracy 0.4765
# Epoch 4 Batch 1000 Loss 2.8611 Accuracy 0.4769
# Epoch 4 Batch 1050 Loss 2.8594 Accuracy 0.4770
# Epoch 4 Batch 1100 Loss 2.8569 Accuracy 0.4774
# Epoch 4 Batch 1150 Loss 2.8540 Accuracy 0.4778
# Epoch 4 Batch 1200 Loss 2.8519 Accuracy 0.4780
# Epoch 4 Batch 1250 Loss 2.8507 Accuracy 0.4780
# Epoch 4 Batch 1300 Loss 2.8482 Accuracy 0.4785
# Epoch 4 Batch 1350 Loss 2.8451 Accuracy 0.4788
# Epoch 4 Batch 1400 Loss 2.8420 Accuracy 0.4791
# Epoch 4 Batch 1450 Loss 2.8405 Accuracy 0.4792
# Epoch 4 Batch 1500 Loss 2.8376 Accuracy 0.4796
# Epoch 4 Batch 1550 Loss 2.8353 Accuracy 0.4799
# Epoch 4 Batch 1600 Loss 2.8328 Accuracy 0.4801
# Epoch 4 Batch 1650 Loss 2.8298 Accuracy 0.4805
# Epoch 4 Batch 1700 Loss 2.8283 Accuracy 0.4807
# Epoch 4 Batch 1750 Loss 2.8269 Accuracy 0.4808
# Epoch 4 Batch 1800 Loss 2.8247 Accuracy 0.4811
# Epoch 4 Batch 1850 Loss 2.8229 Accuracy 0.4813
# Epoch 4 Batch 1900 Loss 2.8211 Accuracy 0.4815
# Epoch 4 Batch 1950 Loss 2.8183 Accuracy 0.4818
# Epoch 4 Batch 2000 Loss 2.8165 Accuracy 0.4820
# Epoch 4 Batch 2050 Loss 2.8150 Accuracy 0.4822
# Epoch 4 Batch 2100 Loss 2.8127 Accuracy 0.4825
# Epoch 4 Batch 2150 Loss 2.8104 Accuracy 0.4828
# Epoch 4 Batch 2200 Loss 2.8085 Accuracy 0.4830
# Epoch 4 Batch 2250 Loss 2.8071 Accuracy 0.4832
# Epoch 4 Batch 2300 Loss 2.8054 Accuracy 0.4834
# Epoch 4 Batch 2350 Loss 2.8033 Accuracy 0.4836
# Epoch 4 Batch 2400 Loss 2.8011 Accuracy 0.4839
# Epoch 4 Batch 2450 Loss 2.7988 Accuracy 0.4842
# Epoch 4 Batch 2500 Loss 2.7973 Accuracy 0.4844
# Epoch 4 Batch 2550 Loss 2.7952 Accuracy 0.4847
# Epoch 4 Batch 2600 Loss 2.7934 Accuracy 0.4849
# Epoch 4 Loss 2.7925 Accuracy 0.4850
# Time taken for 1 epoch: 185.12409377098083 secs
#
# Epoch 5 Batch 0 Loss 2.6149 Accuracy 0.4854
# Epoch 5 Batch 50 Loss 2.6592 Accuracy 0.5012
# Epoch 5 Batch 100 Loss 2.6435 Accuracy 0.5021
# Epoch 5 Batch 150 Loss 2.6568 Accuracy 0.5001
# Epoch 5 Batch 200 Loss 2.6585 Accuracy 0.5003
# Epoch 5 Batch 250 Loss 2.6506 Accuracy 0.5008
# Epoch 5 Batch 300 Loss 2.6568 Accuracy 0.5000
# Epoch 5 Batch 350 Loss 2.6581 Accuracy 0.4999
# Epoch 5 Batch 400 Loss 2.6549 Accuracy 0.5003
# Epoch 5 Batch 450 Loss 2.6564 Accuracy 0.5004
# Epoch 5 Batch 500 Loss 2.6533 Accuracy 0.5009
# Epoch 5 Batch 550 Loss 2.6499 Accuracy 0.5014
# Epoch 5 Batch 600 Loss 2.6512 Accuracy 0.5012
# Epoch 5 Batch 650 Loss 2.6517 Accuracy 0.5011
# Epoch 5 Batch 700 Loss 2.6521 Accuracy 0.5012
# Epoch 5 Batch 750 Loss 2.6489 Accuracy 0.5015
# Epoch 5 Batch 800 Loss 2.6472 Accuracy 0.5017
# Epoch 5 Batch 850 Loss 2.6473 Accuracy 0.5017
# Epoch 5 Batch 900 Loss 2.6457 Accuracy 0.5019
# Epoch 5 Batch 950 Loss 2.6430 Accuracy 0.5023
# Epoch 5 Batch 1000 Loss 2.6417 Accuracy 0.5025
# Epoch 5 Batch 1050 Loss 2.6401 Accuracy 0.5025
# Epoch 5 Batch 1100 Loss 2.6397 Accuracy 0.5026
# Epoch 5 Batch 1150 Loss 2.6392 Accuracy 0.5027
# Epoch 5 Batch 1200 Loss 2.6365 Accuracy 0.5030
# Epoch 5 Batch 1250 Loss 2.6353 Accuracy 0.5033
# Epoch 5 Batch 1300 Loss 2.6338 Accuracy 0.5035
# Epoch 5 Batch 1350 Loss 2.6317 Accuracy 0.5037
# Epoch 5 Batch 1400 Loss 2.6307 Accuracy 0.5039
# Epoch 5 Batch 1450 Loss 2.6294 Accuracy 0.5040
# Epoch 5 Batch 1500 Loss 2.6280 Accuracy 0.5040
# Epoch 5 Batch 1550 Loss 2.6256 Accuracy 0.5045
# Epoch 5 Batch 1600 Loss 2.6242 Accuracy 0.5047
# Epoch 5 Batch 1650 Loss 2.6230 Accuracy 0.5049
# Epoch 5 Batch 1700 Loss 2.6214 Accuracy 0.5051
# Epoch 5 Batch 1750 Loss 2.6206 Accuracy 0.5052
# Epoch 5 Batch 1800 Loss 2.6193 Accuracy 0.5055
# Epoch 5 Batch 1850 Loss 2.6178 Accuracy 0.5056
# Epoch 5 Batch 1900 Loss 2.6170 Accuracy 0.5058
# Epoch 5 Batch 1950 Loss 2.6160 Accuracy 0.5059
# Epoch 5 Batch 2000 Loss 2.6142 Accuracy 0.5061
# Epoch 5 Batch 2050 Loss 2.6132 Accuracy 0.5063
# Epoch 5 Batch 2100 Loss 2.6122 Accuracy 0.5063
# Epoch 5 Batch 2150 Loss 2.6115 Accuracy 0.5064
# Epoch 5 Batch 2200 Loss 2.6105 Accuracy 0.5066
# Epoch 5 Batch 2250 Loss 2.6092 Accuracy 0.5067
# Epoch 5 Batch 2300 Loss 2.6083 Accuracy 0.5069
# Epoch 5 Batch 2350 Loss 2.6070 Accuracy 0.5070
# Epoch 5 Batch 2400 Loss 2.6064 Accuracy 0.5071
# Epoch 5 Batch 2450 Loss 2.6053 Accuracy 0.5072
# Epoch 5 Batch 2500 Loss 2.6042 Accuracy 0.5074
# Epoch 5 Batch 2550 Loss 2.6032 Accuracy 0.5075
# Epoch 5 Batch 2600 Loss 2.6021 Accuracy 0.5076
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 2.6017 Accuracy 0.5077
# Time taken for 1 epoch: 185.24574542045593 secs
#
# Epoch 6 Batch 0 Loss 2.6603 Accuracy 0.4911
# Epoch 6 Batch 50 Loss 2.5147 Accuracy 0.5182
# Epoch 6 Batch 100 Loss 2.5240 Accuracy 0.5167
# Epoch 6 Batch 150 Loss 2.5335 Accuracy 0.5148
# Epoch 6 Batch 200 Loss 2.5329 Accuracy 0.5150
# Epoch 6 Batch 250 Loss 2.5225 Accuracy 0.5164
# Epoch 6 Batch 300 Loss 2.5195 Accuracy 0.5172
# Epoch 6 Batch 350 Loss 2.5166 Accuracy 0.5176
# Epoch 6 Batch 400 Loss 2.5125 Accuracy 0.5181
# Epoch 6 Batch 450 Loss 2.5125 Accuracy 0.5180
# Epoch 6 Batch 500 Loss 2.5096 Accuracy 0.5184
# Epoch 6 Batch 550 Loss 2.5088 Accuracy 0.5185
# Epoch 6 Batch 600 Loss 2.5084 Accuracy 0.5186
# Epoch 6 Batch 650 Loss 2.5084 Accuracy 0.5186
# Epoch 6 Batch 700 Loss 2.5090 Accuracy 0.5185
# Epoch 6 Batch 750 Loss 2.5097 Accuracy 0.5185
# Epoch 6 Batch 800 Loss 2.5082 Accuracy 0.5187
# Epoch 6 Batch 850 Loss 2.5081 Accuracy 0.5189
# Epoch 6 Batch 900 Loss 2.5067 Accuracy 0.5190
# Epoch 6 Batch 950 Loss 2.5054 Accuracy 0.5191
# Epoch 6 Batch 1000 Loss 2.5049 Accuracy 0.5193
# Epoch 6 Batch 1050 Loss 2.5033 Accuracy 0.5195
# Epoch 6 Batch 1100 Loss 2.5026 Accuracy 0.5197
# Epoch 6 Batch 1150 Loss 2.5020 Accuracy 0.5198
# Epoch 6 Batch 1200 Loss 2.5008 Accuracy 0.5199
# Epoch 6 Batch 1250 Loss 2.4994 Accuracy 0.5202
# Epoch 6 Batch 1300 Loss 2.4982 Accuracy 0.5204
# Epoch 6 Batch 1350 Loss 2.4982 Accuracy 0.5204
# Epoch 6 Batch 1400 Loss 2.4976 Accuracy 0.5205
# Epoch 6 Batch 1450 Loss 2.4962 Accuracy 0.5207
# Epoch 6 Batch 1500 Loss 2.4958 Accuracy 0.5208
# Epoch 6 Batch 1550 Loss 2.4949 Accuracy 0.5209
# Epoch 6 Batch 1600 Loss 2.4940 Accuracy 0.5209
# Epoch 6 Batch 1650 Loss 2.4938 Accuracy 0.5210
# Epoch 6 Batch 1700 Loss 2.4926 Accuracy 0.5212
# Epoch 6 Batch 1750 Loss 2.4916 Accuracy 0.5214
# Epoch 6 Batch 1800 Loss 2.4906 Accuracy 0.5216
# Epoch 6 Batch 1850 Loss 2.4899 Accuracy 0.5216
# Epoch 6 Batch 1900 Loss 2.4886 Accuracy 0.5218
# Epoch 6 Batch 1950 Loss 2.4880 Accuracy 0.5218
# Epoch 6 Batch 2000 Loss 2.4873 Accuracy 0.5219
# Epoch 6 Batch 2050 Loss 2.4862 Accuracy 0.5221
# Epoch 6 Batch 2100 Loss 2.4855 Accuracy 0.5222
# Epoch 6 Batch 2150 Loss 2.4854 Accuracy 0.5222
# Epoch 6 Batch 2200 Loss 2.4843 Accuracy 0.5224
# Epoch 6 Batch 2250 Loss 2.4838 Accuracy 0.5224
# Epoch 6 Batch 2300 Loss 2.4835 Accuracy 0.5224
# Epoch 6 Batch 2350 Loss 2.4827 Accuracy 0.5225
# Epoch 6 Batch 2400 Loss 2.4821 Accuracy 0.5226
# Epoch 6 Batch 2450 Loss 2.4812 Accuracy 0.5227
# Epoch 6 Batch 2500 Loss 2.4807 Accuracy 0.5227
# Epoch 6 Batch 2550 Loss 2.4799 Accuracy 0.5228
# Epoch 6 Batch 2600 Loss 2.4798 Accuracy 0.5229
# Epoch 6 Loss 2.4793 Accuracy 0.5229
# Time taken for 1 epoch: 182.89417219161987 secs
#
# Epoch 7 Batch 0 Loss 2.3431 Accuracy 0.5542
# Epoch 7 Batch 50 Loss 2.4235 Accuracy 0.5303
# Epoch 7 Batch 100 Loss 2.4087 Accuracy 0.5315
# Epoch 7 Batch 150 Loss 2.4031 Accuracy 0.5321
# Epoch 7 Batch 200 Loss 2.4080 Accuracy 0.5315
# Epoch 7 Batch 250 Loss 2.4117 Accuracy 0.5308
# Epoch 7 Batch 300 Loss 2.4072 Accuracy 0.5313
# Epoch 7 Batch 350 Loss 2.4102 Accuracy 0.5309
# Epoch 7 Batch 400 Loss 2.4110 Accuracy 0.5308
# Epoch 7 Batch 450 Loss 2.4118 Accuracy 0.5305
# Epoch 7 Batch 500 Loss 2.4102 Accuracy 0.5306
# Epoch 7 Batch 550 Loss 2.4077 Accuracy 0.5311
# Epoch 7 Batch 600 Loss 2.4090 Accuracy 0.5310
# Epoch 7 Batch 650 Loss 2.4101 Accuracy 0.5307
# Epoch 7 Batch 700 Loss 2.4077 Accuracy 0.5310
# Epoch 7 Batch 750 Loss 2.4065 Accuracy 0.5310
# Epoch 7 Batch 800 Loss 2.4055 Accuracy 0.5312
# Epoch 7 Batch 850 Loss 2.4050 Accuracy 0.5314
# Epoch 7 Batch 900 Loss 2.4056 Accuracy 0.5314
# Epoch 7 Batch 950 Loss 2.4062 Accuracy 0.5314
# Epoch 7 Batch 1000 Loss 2.4056 Accuracy 0.5315
# Epoch 7 Batch 1050 Loss 2.4051 Accuracy 0.5316
# Epoch 7 Batch 1100 Loss 2.4049 Accuracy 0.5317
# Epoch 7 Batch 1150 Loss 2.4043 Accuracy 0.5318
# Epoch 7 Batch 1200 Loss 2.4048 Accuracy 0.5318
# Epoch 7 Batch 1250 Loss 2.4046 Accuracy 0.5319
# Epoch 7 Batch 1300 Loss 2.4042 Accuracy 0.5320
# Epoch 7 Batch 1350 Loss 2.4037 Accuracy 0.5321
# Epoch 7 Batch 1400 Loss 2.4023 Accuracy 0.5323
# Epoch 7 Batch 1450 Loss 2.4017 Accuracy 0.5324
# Epoch 7 Batch 1500 Loss 2.4009 Accuracy 0.5325
# Epoch 7 Batch 1550 Loss 2.4005 Accuracy 0.5325
# Epoch 7 Batch 1600 Loss 2.3991 Accuracy 0.5328
# Epoch 7 Batch 1650 Loss 2.3987 Accuracy 0.5329
# Epoch 7 Batch 1700 Loss 2.3982 Accuracy 0.5330
# Epoch 7 Batch 1750 Loss 2.3979 Accuracy 0.5330
# Epoch 7 Batch 1800 Loss 2.3968 Accuracy 0.5331
# Epoch 7 Batch 1850 Loss 2.3960 Accuracy 0.5333
# Epoch 7 Batch 1900 Loss 2.3961 Accuracy 0.5332
# Epoch 7 Batch 1950 Loss 2.3955 Accuracy 0.5333
# Epoch 7 Batch 2000 Loss 2.3945 Accuracy 0.5333
# Epoch 7 Batch 2050 Loss 2.3941 Accuracy 0.5334
# Epoch 7 Batch 2100 Loss 2.3935 Accuracy 0.5335
# Epoch 7 Batch 2150 Loss 2.3933 Accuracy 0.5335
# Epoch 7 Batch 2200 Loss 2.3928 Accuracy 0.5336
# Epoch 7 Batch 2250 Loss 2.3926 Accuracy 0.5336
# Epoch 7 Batch 2300 Loss 2.3927 Accuracy 0.5336
# Epoch 7 Batch 2350 Loss 2.3921 Accuracy 0.5337
# Epoch 7 Batch 2400 Loss 2.3916 Accuracy 0.5338
# Epoch 7 Batch 2450 Loss 2.3909 Accuracy 0.5339
# Epoch 7 Batch 2500 Loss 2.3905 Accuracy 0.5340
# Epoch 7 Batch 2550 Loss 2.3899 Accuracy 0.5340
# Epoch 7 Batch 2600 Loss 2.3900 Accuracy 0.5340
# Epoch 7 Loss 2.3899 Accuracy 0.5340
# Time taken for 1 epoch: 183.95339179039001 secs
#
# Epoch 8 Batch 0 Loss 2.0563 Accuracy 0.5864
# Epoch 8 Batch 50 Loss 2.3535 Accuracy 0.5365
# Epoch 8 Batch 100 Loss 2.3400 Accuracy 0.5400
# Epoch 8 Batch 150 Loss 2.3326 Accuracy 0.5409
# Epoch 8 Batch 200 Loss 2.3281 Accuracy 0.5412
# Epoch 8 Batch 250 Loss 2.3243 Accuracy 0.5418
# Epoch 8 Batch 300 Loss 2.3280 Accuracy 0.5414
# Epoch 8 Batch 350 Loss 2.3251 Accuracy 0.5419
# Epoch 8 Batch 400 Loss 2.3262 Accuracy 0.5420
# Epoch 8 Batch 450 Loss 2.3272 Accuracy 0.5418
# Epoch 8 Batch 500 Loss 2.3319 Accuracy 0.5412
# Epoch 8 Batch 550 Loss 2.3308 Accuracy 0.5415
# Epoch 8 Batch 600 Loss 2.3306 Accuracy 0.5415
# Epoch 8 Batch 650 Loss 2.3300 Accuracy 0.5416
# Epoch 8 Batch 700 Loss 2.3300 Accuracy 0.5415
# Epoch 8 Batch 750 Loss 2.3316 Accuracy 0.5413
# Epoch 8 Batch 800 Loss 2.3322 Accuracy 0.5411
# Epoch 8 Batch 850 Loss 2.3338 Accuracy 0.5410
# Epoch 8 Batch 900 Loss 2.3334 Accuracy 0.5411
# Epoch 8 Batch 950 Loss 2.3339 Accuracy 0.5411
# Epoch 8 Batch 1000 Loss 2.3332 Accuracy 0.5413
# Epoch 8 Batch 1050 Loss 2.3330 Accuracy 0.5413
# Epoch 8 Batch 1100 Loss 2.3320 Accuracy 0.5414
# Epoch 8 Batch 1150 Loss 2.3316 Accuracy 0.5414
# Epoch 8 Batch 1200 Loss 2.3307 Accuracy 0.5416
# Epoch 8 Batch 1250 Loss 2.3297 Accuracy 0.5417
# Epoch 8 Batch 1300 Loss 2.3292 Accuracy 0.5418
# Epoch 8 Batch 1350 Loss 2.3275 Accuracy 0.5420
# Epoch 8 Batch 1400 Loss 2.3280 Accuracy 0.5420
# Epoch 8 Batch 1450 Loss 2.3270 Accuracy 0.5422
# Epoch 8 Batch 1500 Loss 2.3274 Accuracy 0.5422
# Epoch 8 Batch 1550 Loss 2.3265 Accuracy 0.5423
# Epoch 8 Batch 1600 Loss 2.3261 Accuracy 0.5424
# Epoch 8 Batch 1650 Loss 2.3260 Accuracy 0.5425
# Epoch 8 Batch 1700 Loss 2.3262 Accuracy 0.5424
# Epoch 8 Batch 1750 Loss 2.3265 Accuracy 0.5424
# Epoch 8 Batch 1800 Loss 2.3264 Accuracy 0.5424
# Epoch 8 Batch 1850 Loss 2.3265 Accuracy 0.5423
# Epoch 8 Batch 1900 Loss 2.3260 Accuracy 0.5424
# Epoch 8 Batch 1950 Loss 2.3255 Accuracy 0.5425
# Epoch 8 Batch 2000 Loss 2.3243 Accuracy 0.5427
# Epoch 8 Batch 2050 Loss 2.3232 Accuracy 0.5429
# Epoch 8 Batch 2100 Loss 2.3224 Accuracy 0.5429
# Epoch 8 Batch 2150 Loss 2.3225 Accuracy 0.5429
# Epoch 8 Batch 2200 Loss 2.3223 Accuracy 0.5430
# Epoch 8 Batch 2250 Loss 2.3222 Accuracy 0.5431
# Epoch 8 Batch 2300 Loss 2.3220 Accuracy 0.5431
# Epoch 8 Batch 2350 Loss 2.3212 Accuracy 0.5432
# Epoch 8 Batch 2400 Loss 2.3210 Accuracy 0.5432
# Epoch 8 Batch 2450 Loss 2.3208 Accuracy 0.5432
# Epoch 8 Batch 2500 Loss 2.3210 Accuracy 0.5432
# Epoch 8 Batch 2550 Loss 2.3205 Accuracy 0.5432
# Epoch 8 Batch 2600 Loss 2.3200 Accuracy 0.5433
# Epoch 8 Loss 2.3201 Accuracy 0.5433
# Time taken for 1 epoch: 180.78954076766968 secs
#
# Epoch 9 Batch 0 Loss 2.2987 Accuracy 0.5404
# Epoch 9 Batch 50 Loss 2.2864 Accuracy 0.5476
# Epoch 9 Batch 100 Loss 2.2840 Accuracy 0.5487
# Epoch 9 Batch 150 Loss 2.2808 Accuracy 0.5480
# Epoch 9 Batch 200 Loss 2.2719 Accuracy 0.5495
# Epoch 9 Batch 250 Loss 2.2746 Accuracy 0.5494
# Epoch 9 Batch 300 Loss 2.2764 Accuracy 0.5490
# Epoch 9 Batch 350 Loss 2.2793 Accuracy 0.5484
# Epoch 9 Batch 400 Loss 2.2778 Accuracy 0.5485
# Epoch 9 Batch 450 Loss 2.2774 Accuracy 0.5487
# Epoch 9 Batch 500 Loss 2.2776 Accuracy 0.5486
# Epoch 9 Batch 550 Loss 2.2802 Accuracy 0.5482
# Epoch 9 Batch 600 Loss 2.2796 Accuracy 0.5481
# Epoch 9 Batch 650 Loss 2.2781 Accuracy 0.5482
# Epoch 9 Batch 700 Loss 2.2765 Accuracy 0.5485
# Epoch 9 Batch 750 Loss 2.2771 Accuracy 0.5485
# Epoch 9 Batch 800 Loss 2.2760 Accuracy 0.5487
# Epoch 9 Batch 850 Loss 2.2764 Accuracy 0.5486
# Epoch 9 Batch 900 Loss 2.2759 Accuracy 0.5484
# Epoch 9 Batch 950 Loss 2.2755 Accuracy 0.5484
# Epoch 9 Batch 1000 Loss 2.2760 Accuracy 0.5484
# Epoch 9 Batch 1050 Loss 2.2758 Accuracy 0.5483
# Epoch 9 Batch 1100 Loss 2.2751 Accuracy 0.5485
# Epoch 9 Batch 1150 Loss 2.2752 Accuracy 0.5485
# Epoch 9 Batch 1200 Loss 2.2746 Accuracy 0.5487
# Epoch 9 Batch 1250 Loss 2.2721 Accuracy 0.5491
# Epoch 9 Batch 1300 Loss 2.2717 Accuracy 0.5492
# Epoch 9 Batch 1350 Loss 2.2719 Accuracy 0.5493
# Epoch 9 Batch 1400 Loss 2.2716 Accuracy 0.5494
# Epoch 9 Batch 1450 Loss 2.2708 Accuracy 0.5495
# Epoch 9 Batch 1500 Loss 2.2701 Accuracy 0.5497
# Epoch 9 Batch 1550 Loss 2.2698 Accuracy 0.5498
# Epoch 9 Batch 1600 Loss 2.2698 Accuracy 0.5497
# Epoch 9 Batch 1650 Loss 2.2693 Accuracy 0.5499
# Epoch 9 Batch 1700 Loss 2.2691 Accuracy 0.5499
# Epoch 9 Batch 1750 Loss 2.2691 Accuracy 0.5498
# Epoch 9 Batch 1800 Loss 2.2693 Accuracy 0.5498
# Epoch 9 Batch 1850 Loss 2.2699 Accuracy 0.5498
# Epoch 9 Batch 1900 Loss 2.2701 Accuracy 0.5497
# Epoch 9 Batch 1950 Loss 2.2693 Accuracy 0.5499
# Epoch 9 Batch 2000 Loss 2.2685 Accuracy 0.5500
# Epoch 9 Batch 2050 Loss 2.2681 Accuracy 0.5501
# Epoch 9 Batch 2100 Loss 2.2685 Accuracy 0.5501
# Epoch 9 Batch 2150 Loss 2.2677 Accuracy 0.5503
# Epoch 9 Batch 2200 Loss 2.2671 Accuracy 0.5503
# Epoch 9 Batch 2250 Loss 2.2674 Accuracy 0.5503
# Epoch 9 Batch 2300 Loss 2.2667 Accuracy 0.5504
# Epoch 9 Batch 2350 Loss 2.2663 Accuracy 0.5504
# Epoch 9 Batch 2400 Loss 2.2662 Accuracy 0.5505
# Epoch 9 Batch 2450 Loss 2.2661 Accuracy 0.5505
# Epoch 9 Batch 2500 Loss 2.2657 Accuracy 0.5505
# Epoch 9 Batch 2550 Loss 2.2655 Accuracy 0.5505
# Epoch 9 Batch 2600 Loss 2.2652 Accuracy 0.5506
# Epoch 9 Loss 2.2651 Accuracy 0.5506
# Time taken for 1 epoch: 182.03491139411926 secs
#
# Epoch 10 Batch 0 Loss 2.1657 Accuracy 0.5664
# Epoch 10 Batch 50 Loss 2.2164 Accuracy 0.5567
# Epoch 10 Batch 100 Loss 2.2228 Accuracy 0.5561
# Epoch 10 Batch 150 Loss 2.2253 Accuracy 0.5558
# Epoch 10 Batch 200 Loss 2.2274 Accuracy 0.5548
# Epoch 10 Batch 250 Loss 2.2288 Accuracy 0.5544
# Epoch 10 Batch 300 Loss 2.2282 Accuracy 0.5545
# Epoch 10 Batch 350 Loss 2.2241 Accuracy 0.5554
# Epoch 10 Batch 400 Loss 2.2262 Accuracy 0.5555
# Epoch 10 Batch 450 Loss 2.2269 Accuracy 0.5555
# Epoch 10 Batch 500 Loss 2.2260 Accuracy 0.5555
# Epoch 10 Batch 550 Loss 2.2258 Accuracy 0.5555
# Epoch 10 Batch 600 Loss 2.2243 Accuracy 0.5557
# Epoch 10 Batch 650 Loss 2.2251 Accuracy 0.5556
# Epoch 10 Batch 700 Loss 2.2238 Accuracy 0.5560
# Epoch 10 Batch 750 Loss 2.2239 Accuracy 0.5559
# Epoch 10 Batch 800 Loss 2.2236 Accuracy 0.5560
# Epoch 10 Batch 850 Loss 2.2238 Accuracy 0.5559
# Epoch 10 Batch 900 Loss 2.2260 Accuracy 0.5556
# Epoch 10 Batch 950 Loss 2.2258 Accuracy 0.5556
# Epoch 10 Batch 1000 Loss 2.2250 Accuracy 0.5556
# Epoch 10 Batch 1050 Loss 2.2262 Accuracy 0.5555
# Epoch 10 Batch 1100 Loss 2.2263 Accuracy 0.5555
# Epoch 10 Batch 1150 Loss 2.2268 Accuracy 0.5555
# Epoch 10 Batch 1200 Loss 2.2273 Accuracy 0.5555
# Epoch 10 Batch 1250 Loss 2.2262 Accuracy 0.5556
# Epoch 10 Batch 1300 Loss 2.2256 Accuracy 0.5558
# Epoch 10 Batch 1350 Loss 2.2248 Accuracy 0.5559
# Epoch 10 Batch 1400 Loss 2.2254 Accuracy 0.5557
# Epoch 10 Batch 1450 Loss 2.2244 Accuracy 0.5559
# Epoch 10 Batch 1500 Loss 2.2237 Accuracy 0.5561
# Epoch 10 Batch 1550 Loss 2.2233 Accuracy 0.5562
# Epoch 10 Batch 1600 Loss 2.2233 Accuracy 0.5562
# Epoch 10 Batch 1650 Loss 2.2234 Accuracy 0.5562
# Epoch 10 Batch 1700 Loss 2.2233 Accuracy 0.5562
# Epoch 10 Batch 1750 Loss 2.2227 Accuracy 0.5563
# Epoch 10 Batch 1800 Loss 2.2229 Accuracy 0.5563
# Epoch 10 Batch 1850 Loss 2.2228 Accuracy 0.5563
# Epoch 10 Batch 1900 Loss 2.2222 Accuracy 0.5565
# Epoch 10 Batch 1950 Loss 2.2218 Accuracy 0.5565
# Epoch 10 Batch 2000 Loss 2.2215 Accuracy 0.5565
# Epoch 10 Batch 2050 Loss 2.2213 Accuracy 0.5565
# Epoch 10 Batch 2100 Loss 2.2210 Accuracy 0.5565
# Epoch 10 Batch 2150 Loss 2.2215 Accuracy 0.5565
# Epoch 10 Batch 2200 Loss 2.2214 Accuracy 0.5565
# Epoch 10 Batch 2250 Loss 2.2212 Accuracy 0.5565
# Epoch 10 Batch 2300 Loss 2.2212 Accuracy 0.5566
# Epoch 10 Batch 2350 Loss 2.2211 Accuracy 0.5566
# Epoch 10 Batch 2400 Loss 2.2206 Accuracy 0.5567
# Epoch 10 Batch 2450 Loss 2.2203 Accuracy 0.5567
# Epoch 10 Batch 2500 Loss 2.2199 Accuracy 0.5567
# Epoch 10 Batch 2550 Loss 2.2200 Accuracy 0.5567
# Epoch 10 Batch 2600 Loss 2.2207 Accuracy 0.5567
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 2.2206 Accuracy 0.5567
# Time taken for 1 epoch: 181.03170204162598 secs
#
# Epoch 11 Batch 0 Loss 2.1789 Accuracy 0.5562
# Epoch 11 Batch 50 Loss 2.1733 Accuracy 0.5667
# Epoch 11 Batch 100 Loss 2.1668 Accuracy 0.5665
# Epoch 11 Batch 150 Loss 2.1728 Accuracy 0.5649
# Epoch 11 Batch 200 Loss 2.1737 Accuracy 0.5641
# Epoch 11 Batch 250 Loss 2.1730 Accuracy 0.5637
# Epoch 11 Batch 300 Loss 2.1708 Accuracy 0.5638
# Epoch 11 Batch 350 Loss 2.1754 Accuracy 0.5631
# Epoch 11 Batch 400 Loss 2.1808 Accuracy 0.5621
# Epoch 11 Batch 450 Loss 2.1815 Accuracy 0.5619
# Epoch 11 Batch 500 Loss 2.1835 Accuracy 0.5615
# Epoch 11 Batch 550 Loss 2.1836 Accuracy 0.5612
# Epoch 11 Batch 600 Loss 2.1861 Accuracy 0.5608
# Epoch 11 Batch 650 Loss 2.1851 Accuracy 0.5609
# Epoch 11 Batch 700 Loss 2.1857 Accuracy 0.5607
# Epoch 11 Batch 750 Loss 2.1858 Accuracy 0.5608
# Epoch 11 Batch 800 Loss 2.1860 Accuracy 0.5607
# Epoch 11 Batch 850 Loss 2.1869 Accuracy 0.5607
# Epoch 11 Batch 900 Loss 2.1872 Accuracy 0.5606
# Epoch 11 Batch 950 Loss 2.1866 Accuracy 0.5609
# Epoch 11 Batch 1000 Loss 2.1847 Accuracy 0.5611
# Epoch 11 Batch 1050 Loss 2.1842 Accuracy 0.5612
# Epoch 11 Batch 1100 Loss 2.1844 Accuracy 0.5612
# Epoch 11 Batch 1150 Loss 2.1840 Accuracy 0.5613
# Epoch 11 Batch 1200 Loss 2.1849 Accuracy 0.5613
# Epoch 11 Batch 1250 Loss 2.1844 Accuracy 0.5614
# Epoch 11 Batch 1300 Loss 2.1836 Accuracy 0.5615
# Epoch 11 Batch 1350 Loss 2.1835 Accuracy 0.5614
# Epoch 11 Batch 1400 Loss 2.1838 Accuracy 0.5614
# Epoch 11 Batch 1450 Loss 2.1833 Accuracy 0.5615
# Epoch 11 Batch 1500 Loss 2.1824 Accuracy 0.5617
# Epoch 11 Batch 1550 Loss 2.1822 Accuracy 0.5618
# Epoch 11 Batch 1600 Loss 2.1823 Accuracy 0.5618
# Epoch 11 Batch 1650 Loss 2.1822 Accuracy 0.5618
# Epoch 11 Batch 1700 Loss 2.1819 Accuracy 0.5618
# Epoch 11 Batch 1750 Loss 2.1810 Accuracy 0.5619
# Epoch 11 Batch 1800 Loss 2.1801 Accuracy 0.5621
# Epoch 11 Batch 1850 Loss 2.1802 Accuracy 0.5621
# Epoch 11 Batch 1900 Loss 2.1810 Accuracy 0.5620
# Epoch 11 Batch 1950 Loss 2.1809 Accuracy 0.5620
# Epoch 11 Batch 2000 Loss 2.1807 Accuracy 0.5620
# Epoch 11 Batch 2050 Loss 2.1804 Accuracy 0.5621
# Epoch 11 Batch 2100 Loss 2.1804 Accuracy 0.5621
# Epoch 11 Batch 2150 Loss 2.1808 Accuracy 0.5621
# Epoch 11 Batch 2200 Loss 2.1808 Accuracy 0.5621
# Epoch 11 Batch 2250 Loss 2.1808 Accuracy 0.5621
# Epoch 11 Batch 2300 Loss 2.1807 Accuracy 0.5621
# Epoch 11 Batch 2350 Loss 2.1811 Accuracy 0.5620
# Epoch 11 Batch 2400 Loss 2.1812 Accuracy 0.5621
# Epoch 11 Batch 2450 Loss 2.1813 Accuracy 0.5620
# Epoch 11 Batch 2500 Loss 2.1808 Accuracy 0.5621
# Epoch 11 Batch 2550 Loss 2.1809 Accuracy 0.5621
# Epoch 11 Batch 2600 Loss 2.1809 Accuracy 0.5621
# Epoch 11 Loss 2.1809 Accuracy 0.5621
# Time taken for 1 epoch: 181.66103649139404 secs
#
# Epoch 12 Batch 0 Loss 2.1408 Accuracy 0.5582
# Epoch 12 Batch 50 Loss 2.1327 Accuracy 0.5672
# Epoch 12 Batch 100 Loss 2.1217 Accuracy 0.5685
# Epoch 12 Batch 150 Loss 2.1275 Accuracy 0.5679
# Epoch 12 Batch 200 Loss 2.1316 Accuracy 0.5680
# Epoch 12 Batch 250 Loss 2.1360 Accuracy 0.5675
# Epoch 12 Batch 300 Loss 2.1416 Accuracy 0.5668
# Epoch 12 Batch 350 Loss 2.1423 Accuracy 0.5666
# Epoch 12 Batch 400 Loss 2.1441 Accuracy 0.5664
# Epoch 12 Batch 450 Loss 2.1406 Accuracy 0.5670
# Epoch 12 Batch 500 Loss 2.1425 Accuracy 0.5668
# Epoch 12 Batch 550 Loss 2.1448 Accuracy 0.5664
# Epoch 12 Batch 600 Loss 2.1450 Accuracy 0.5662
# Epoch 12 Batch 650 Loss 2.1457 Accuracy 0.5663
# Epoch 12 Batch 700 Loss 2.1472 Accuracy 0.5660
# Epoch 12 Batch 750 Loss 2.1473 Accuracy 0.5659
# Epoch 12 Batch 800 Loss 2.1485 Accuracy 0.5659
# Epoch 12 Batch 850 Loss 2.1476 Accuracy 0.5660
# Epoch 12 Batch 900 Loss 2.1472 Accuracy 0.5661
# Epoch 12 Batch 950 Loss 2.1493 Accuracy 0.5659
# Epoch 12 Batch 1000 Loss 2.1497 Accuracy 0.5658
# Epoch 12 Batch 1050 Loss 2.1492 Accuracy 0.5660
# Epoch 12 Batch 1100 Loss 2.1503 Accuracy 0.5659
# Epoch 12 Batch 1150 Loss 2.1504 Accuracy 0.5659
# Epoch 12 Batch 1200 Loss 2.1509 Accuracy 0.5658
# Epoch 12 Batch 1250 Loss 2.1505 Accuracy 0.5659
# Epoch 12 Batch 1300 Loss 2.1505 Accuracy 0.5660
# Epoch 12 Batch 1350 Loss 2.1495 Accuracy 0.5662
# Epoch 12 Batch 1400 Loss 2.1491 Accuracy 0.5662
# Epoch 12 Batch 1450 Loss 2.1480 Accuracy 0.5664
# Epoch 12 Batch 1500 Loss 2.1480 Accuracy 0.5665
# Epoch 12 Batch 1550 Loss 2.1479 Accuracy 0.5665
# Epoch 12 Batch 1600 Loss 2.1475 Accuracy 0.5666
# Epoch 12 Batch 1650 Loss 2.1486 Accuracy 0.5665
# Epoch 12 Batch 1700 Loss 2.1490 Accuracy 0.5664
# Epoch 12 Batch 1750 Loss 2.1485 Accuracy 0.5665
# Epoch 12 Batch 1800 Loss 2.1486 Accuracy 0.5664
# Epoch 12 Batch 1850 Loss 2.1486 Accuracy 0.5665
# Epoch 12 Batch 1900 Loss 2.1488 Accuracy 0.5665
# Epoch 12 Batch 1950 Loss 2.1484 Accuracy 0.5666
# Epoch 12 Batch 2000 Loss 2.1483 Accuracy 0.5666
# Epoch 12 Batch 2050 Loss 2.1482 Accuracy 0.5666
# Epoch 12 Batch 2100 Loss 2.1485 Accuracy 0.5666
# Epoch 12 Batch 2150 Loss 2.1481 Accuracy 0.5667
# Epoch 12 Batch 2200 Loss 2.1484 Accuracy 0.5666
# Epoch 12 Batch 2250 Loss 2.1482 Accuracy 0.5667
# Epoch 12 Batch 2300 Loss 2.1477 Accuracy 0.5667
# Epoch 12 Batch 2350 Loss 2.1477 Accuracy 0.5667
# Epoch 12 Batch 2400 Loss 2.1468 Accuracy 0.5669
# Epoch 12 Batch 2450 Loss 2.1470 Accuracy 0.5669
# Epoch 12 Batch 2500 Loss 2.1476 Accuracy 0.5668
# Epoch 12 Batch 2550 Loss 2.1477 Accuracy 0.5668
# Epoch 12 Batch 2600 Loss 2.1476 Accuracy 0.5668
# Epoch 12 Loss 2.1477 Accuracy 0.5668
# Time taken for 1 epoch: 180.1011300086975 secs
#
# Epoch 13 Batch 0 Loss 2.2492 Accuracy 0.5482
# Epoch 13 Batch 50 Loss 2.1148 Accuracy 0.5701
# Epoch 13 Batch 100 Loss 2.1125 Accuracy 0.5713
# Epoch 13 Batch 150 Loss 2.1164 Accuracy 0.5705
# Epoch 13 Batch 200 Loss 2.1160 Accuracy 0.5703
# Epoch 13 Batch 250 Loss 2.1176 Accuracy 0.5700
# Epoch 13 Batch 300 Loss 2.1242 Accuracy 0.5692
# Epoch 13 Batch 350 Loss 2.1271 Accuracy 0.5688
# Epoch 13 Batch 400 Loss 2.1249 Accuracy 0.5693
# Epoch 13 Batch 450 Loss 2.1241 Accuracy 0.5696
# Epoch 13 Batch 500 Loss 2.1255 Accuracy 0.5695
# Epoch 13 Batch 550 Loss 2.1229 Accuracy 0.5701
# Epoch 13 Batch 600 Loss 2.1240 Accuracy 0.5699
# Epoch 13 Batch 650 Loss 2.1234 Accuracy 0.5701
# Epoch 13 Batch 700 Loss 2.1245 Accuracy 0.5700
# Epoch 13 Batch 750 Loss 2.1245 Accuracy 0.5699
# Epoch 13 Batch 800 Loss 2.1242 Accuracy 0.5700
# Epoch 13 Batch 850 Loss 2.1242 Accuracy 0.5700
# Epoch 13 Batch 900 Loss 2.1226 Accuracy 0.5702
# Epoch 13 Batch 950 Loss 2.1231 Accuracy 0.5702
# Epoch 13 Batch 1000 Loss 2.1225 Accuracy 0.5702
# Epoch 13 Batch 1050 Loss 2.1228 Accuracy 0.5701
# Epoch 13 Batch 1100 Loss 2.1225 Accuracy 0.5702
# Epoch 13 Batch 1150 Loss 2.1233 Accuracy 0.5701
# Epoch 13 Batch 1200 Loss 2.1229 Accuracy 0.5701
# Epoch 13 Batch 1250 Loss 2.1220 Accuracy 0.5702
# Epoch 13 Batch 1300 Loss 2.1213 Accuracy 0.5704
# Epoch 13 Batch 1350 Loss 2.1212 Accuracy 0.5704
# Epoch 13 Batch 1400 Loss 2.1213 Accuracy 0.5704
# Epoch 13 Batch 1450 Loss 2.1213 Accuracy 0.5704
# Epoch 13 Batch 1500 Loss 2.1216 Accuracy 0.5703
# Epoch 13 Batch 1550 Loss 2.1209 Accuracy 0.5705
# Epoch 13 Batch 1600 Loss 2.1204 Accuracy 0.5705
# Epoch 13 Batch 1650 Loss 2.1199 Accuracy 0.5706
# Epoch 13 Batch 1700 Loss 2.1193 Accuracy 0.5707
# Epoch 13 Batch 1750 Loss 2.1197 Accuracy 0.5707
# Epoch 13 Batch 1800 Loss 2.1198 Accuracy 0.5707
# Epoch 13 Batch 1850 Loss 2.1207 Accuracy 0.5705
# Epoch 13 Batch 1900 Loss 2.1205 Accuracy 0.5705
# Epoch 13 Batch 1950 Loss 2.1204 Accuracy 0.5706
# Epoch 13 Batch 2000 Loss 2.1202 Accuracy 0.5706
# Epoch 13 Batch 2050 Loss 2.1199 Accuracy 0.5706
# Epoch 13 Batch 2100 Loss 2.1195 Accuracy 0.5707
# Epoch 13 Batch 2150 Loss 2.1194 Accuracy 0.5707
# Epoch 13 Batch 2200 Loss 2.1193 Accuracy 0.5707
# Epoch 13 Batch 2250 Loss 2.1194 Accuracy 0.5707
# Epoch 13 Batch 2300 Loss 2.1186 Accuracy 0.5708
# Epoch 13 Batch 2350 Loss 2.1191 Accuracy 0.5707
# Epoch 13 Batch 2400 Loss 2.1191 Accuracy 0.5707
# Epoch 13 Batch 2450 Loss 2.1194 Accuracy 0.5707
# Epoch 13 Batch 2500 Loss 2.1191 Accuracy 0.5708
# Epoch 13 Batch 2550 Loss 2.1193 Accuracy 0.5707
# Epoch 13 Batch 2600 Loss 2.1191 Accuracy 0.5708
# Epoch 13 Loss 2.1195 Accuracy 0.5707
# Time taken for 1 epoch: 181.33762192726135 secs
#
# Epoch 14 Batch 0 Loss 1.9522 Accuracy 0.5977
# Epoch 14 Batch 50 Loss 2.0793 Accuracy 0.5761
# Epoch 14 Batch 100 Loss 2.0793 Accuracy 0.5766
# Epoch 14 Batch 150 Loss 2.0767 Accuracy 0.5762
# Epoch 14 Batch 200 Loss 2.0835 Accuracy 0.5751
# Epoch 14 Batch 250 Loss 2.0905 Accuracy 0.5739
# Epoch 14 Batch 300 Loss 2.0887 Accuracy 0.5742
# Epoch 14 Batch 350 Loss 2.0910 Accuracy 0.5739
# Epoch 14 Batch 400 Loss 2.0930 Accuracy 0.5737
# Epoch 14 Batch 450 Loss 2.0920 Accuracy 0.5739
# Epoch 14 Batch 500 Loss 2.0937 Accuracy 0.5736
# Epoch 14 Batch 550 Loss 2.0941 Accuracy 0.5735
# Epoch 14 Batch 600 Loss 2.0935 Accuracy 0.5738
# Epoch 14 Batch 650 Loss 2.0938 Accuracy 0.5737
# Epoch 14 Batch 700 Loss 2.0935 Accuracy 0.5737
# Epoch 14 Batch 750 Loss 2.0942 Accuracy 0.5737
# Epoch 14 Batch 800 Loss 2.0960 Accuracy 0.5734
# Epoch 14 Batch 850 Loss 2.0958 Accuracy 0.5734
# Epoch 14 Batch 900 Loss 2.0968 Accuracy 0.5734
# Epoch 14 Batch 950 Loss 2.0963 Accuracy 0.5736
# Epoch 14 Batch 1000 Loss 2.0953 Accuracy 0.5738
# Epoch 14 Batch 1050 Loss 2.0939 Accuracy 0.5740
# Epoch 14 Batch 1100 Loss 2.0938 Accuracy 0.5741
# Epoch 14 Batch 1150 Loss 2.0942 Accuracy 0.5740
# Epoch 14 Batch 1200 Loss 2.0943 Accuracy 0.5741
# Epoch 14 Batch 1250 Loss 2.0946 Accuracy 0.5741
# Epoch 14 Batch 1300 Loss 2.0940 Accuracy 0.5743
# Epoch 14 Batch 1350 Loss 2.0935 Accuracy 0.5743
# Epoch 14 Batch 1400 Loss 2.0937 Accuracy 0.5743
# Epoch 14 Batch 1450 Loss 2.0944 Accuracy 0.5742
# Epoch 14 Batch 1500 Loss 2.0933 Accuracy 0.5744
# Epoch 14 Batch 1550 Loss 2.0933 Accuracy 0.5744
# Epoch 14 Batch 1600 Loss 2.0929 Accuracy 0.5746
# Epoch 14 Batch 1650 Loss 2.0935 Accuracy 0.5745
# Epoch 14 Batch 1700 Loss 2.0940 Accuracy 0.5745
# Epoch 14 Batch 1750 Loss 2.0940 Accuracy 0.5745
# Epoch 14 Batch 1800 Loss 2.0943 Accuracy 0.5744
# Epoch 14 Batch 1850 Loss 2.0944 Accuracy 0.5744
# Epoch 14 Batch 1900 Loss 2.0943 Accuracy 0.5744
# Epoch 14 Batch 1950 Loss 2.0942 Accuracy 0.5744
# Epoch 14 Batch 2000 Loss 2.0937 Accuracy 0.5745
# Epoch 14 Batch 2050 Loss 2.0937 Accuracy 0.5745
# Epoch 14 Batch 2100 Loss 2.0941 Accuracy 0.5745
# Epoch 14 Batch 2150 Loss 2.0940 Accuracy 0.5745
# Epoch 14 Batch 2200 Loss 2.0944 Accuracy 0.5745
# Epoch 14 Batch 2250 Loss 2.0949 Accuracy 0.5745
# Epoch 14 Batch 2300 Loss 2.0948 Accuracy 0.5746
# Epoch 14 Batch 2350 Loss 2.0939 Accuracy 0.5747
# Epoch 14 Batch 2400 Loss 2.0940 Accuracy 0.5747
# Epoch 14 Batch 2450 Loss 2.0941 Accuracy 0.5746
# Epoch 14 Batch 2500 Loss 2.0941 Accuracy 0.5746
# Epoch 14 Batch 2550 Loss 2.0938 Accuracy 0.5746
# Epoch 14 Batch 2600 Loss 2.0936 Accuracy 0.5746
# Epoch 14 Loss 2.0938 Accuracy 0.5746
# Time taken for 1 epoch: 179.7009289264679 secs
#
# Epoch 15 Batch 0 Loss 2.0550 Accuracy 0.5705
# Epoch 15 Batch 50 Loss 2.0805 Accuracy 0.5746
# Epoch 15 Batch 100 Loss 2.0684 Accuracy 0.5763
# Epoch 15 Batch 150 Loss 2.0696 Accuracy 0.5767
# Epoch 15 Batch 200 Loss 2.0695 Accuracy 0.5771
# Epoch 15 Batch 250 Loss 2.0723 Accuracy 0.5772
# Epoch 15 Batch 300 Loss 2.0725 Accuracy 0.5773
# Epoch 15 Batch 350 Loss 2.0731 Accuracy 0.5773
# Epoch 15 Batch 400 Loss 2.0697 Accuracy 0.5776
# Epoch 15 Batch 450 Loss 2.0708 Accuracy 0.5774
# Epoch 15 Batch 500 Loss 2.0729 Accuracy 0.5771
# Epoch 15 Batch 550 Loss 2.0725 Accuracy 0.5773
# Epoch 15 Batch 600 Loss 2.0714 Accuracy 0.5775
# Epoch 15 Batch 650 Loss 2.0716 Accuracy 0.5776
# Epoch 15 Batch 700 Loss 2.0720 Accuracy 0.5774
# Epoch 15 Batch 750 Loss 2.0726 Accuracy 0.5774
# Epoch 15 Batch 800 Loss 2.0719 Accuracy 0.5775
# Epoch 15 Batch 850 Loss 2.0717 Accuracy 0.5776
# Epoch 15 Batch 900 Loss 2.0716 Accuracy 0.5777
# Epoch 15 Batch 950 Loss 2.0712 Accuracy 0.5777
# Epoch 15 Batch 1000 Loss 2.0718 Accuracy 0.5776
# Epoch 15 Batch 1050 Loss 2.0718 Accuracy 0.5777
# Epoch 15 Batch 1100 Loss 2.0718 Accuracy 0.5778
# Epoch 15 Batch 1150 Loss 2.0718 Accuracy 0.5778
# Epoch 15 Batch 1200 Loss 2.0708 Accuracy 0.5780
# Epoch 15 Batch 1250 Loss 2.0699 Accuracy 0.5781
# Epoch 15 Batch 1300 Loss 2.0693 Accuracy 0.5782
# Epoch 15 Batch 1350 Loss 2.0700 Accuracy 0.5780
# Epoch 15 Batch 1400 Loss 2.0711 Accuracy 0.5780
# Epoch 15 Batch 1450 Loss 2.0713 Accuracy 0.5779
# Epoch 15 Batch 1500 Loss 2.0710 Accuracy 0.5779
# Epoch 15 Batch 1550 Loss 2.0703 Accuracy 0.5781
# Epoch 15 Batch 1600 Loss 2.0699 Accuracy 0.5781
# Epoch 15 Batch 1650 Loss 2.0702 Accuracy 0.5781
# Epoch 15 Batch 1700 Loss 2.0702 Accuracy 0.5781
# Epoch 15 Batch 1750 Loss 2.0702 Accuracy 0.5781
# Epoch 15 Batch 1800 Loss 2.0702 Accuracy 0.5781
# Epoch 15 Batch 1850 Loss 2.0707 Accuracy 0.5779
# Epoch 15 Batch 1900 Loss 2.0713 Accuracy 0.5778
# Epoch 15 Batch 1950 Loss 2.0712 Accuracy 0.5778
# Epoch 15 Batch 2000 Loss 2.0710 Accuracy 0.5778
# Epoch 15 Batch 2050 Loss 2.0709 Accuracy 0.5778
# Epoch 15 Batch 2100 Loss 2.0716 Accuracy 0.5777
# Epoch 15 Batch 2150 Loss 2.0716 Accuracy 0.5778
# Epoch 15 Batch 2200 Loss 2.0718 Accuracy 0.5777
# Epoch 15 Batch 2250 Loss 2.0717 Accuracy 0.5778
# Epoch 15 Batch 2300 Loss 2.0715 Accuracy 0.5778
# Epoch 15 Batch 2350 Loss 2.0715 Accuracy 0.5778
# Epoch 15 Batch 2400 Loss 2.0718 Accuracy 0.5778
# Epoch 15 Batch 2450 Loss 2.0714 Accuracy 0.5778
# Epoch 15 Batch 2500 Loss 2.0717 Accuracy 0.5778
# Epoch 15 Batch 2550 Loss 2.0720 Accuracy 0.5777
# Epoch 15 Batch 2600 Loss 2.0720 Accuracy 0.5777
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 2.0721 Accuracy 0.5777
# Time taken for 1 epoch: 183.19597005844116 secs
#
# Epoch 16 Batch 0 Loss 1.9290 Accuracy 0.5887
# Epoch 16 Batch 50 Loss 2.0240 Accuracy 0.5836
# Epoch 16 Batch 100 Loss 2.0429 Accuracy 0.5819
# Epoch 16 Batch 150 Loss 2.0450 Accuracy 0.5816
# Epoch 16 Batch 200 Loss 2.0490 Accuracy 0.5808
# Epoch 16 Batch 250 Loss 2.0509 Accuracy 0.5804
# Epoch 16 Batch 300 Loss 2.0497 Accuracy 0.5806
# Epoch 16 Batch 350 Loss 2.0504 Accuracy 0.5805
# Epoch 16 Batch 400 Loss 2.0498 Accuracy 0.5806
# Epoch 16 Batch 450 Loss 2.0492 Accuracy 0.5805
# Epoch 16 Batch 500 Loss 2.0501 Accuracy 0.5802
# Epoch 16 Batch 550 Loss 2.0488 Accuracy 0.5804
# Epoch 16 Batch 600 Loss 2.0490 Accuracy 0.5805
# Epoch 16 Batch 650 Loss 2.0502 Accuracy 0.5803
# Epoch 16 Batch 700 Loss 2.0507 Accuracy 0.5801
# Epoch 16 Batch 750 Loss 2.0503 Accuracy 0.5802
# Epoch 16 Batch 800 Loss 2.0514 Accuracy 0.5802
# Epoch 16 Batch 850 Loss 2.0511 Accuracy 0.5803
# Epoch 16 Batch 900 Loss 2.0505 Accuracy 0.5804
# Epoch 16 Batch 950 Loss 2.0506 Accuracy 0.5803
# Epoch 16 Batch 1000 Loss 2.0507 Accuracy 0.5804
# Epoch 16 Batch 1050 Loss 2.0512 Accuracy 0.5802
# Epoch 16 Batch 1100 Loss 2.0512 Accuracy 0.5801
# Epoch 16 Batch 1150 Loss 2.0508 Accuracy 0.5801
# Epoch 16 Batch 1200 Loss 2.0501 Accuracy 0.5802
# Epoch 16 Batch 1250 Loss 2.0506 Accuracy 0.5802
# Epoch 16 Batch 1300 Loss 2.0510 Accuracy 0.5802
# Epoch 16 Batch 1350 Loss 2.0507 Accuracy 0.5803
# Epoch 16 Batch 1400 Loss 2.0515 Accuracy 0.5802
# Epoch 16 Batch 1450 Loss 2.0510 Accuracy 0.5804
# Epoch 16 Batch 1500 Loss 2.0507 Accuracy 0.5805
# Epoch 16 Batch 1550 Loss 2.0504 Accuracy 0.5805
# Epoch 16 Batch 1600 Loss 2.0500 Accuracy 0.5806
# Epoch 16 Batch 1650 Loss 2.0505 Accuracy 0.5806
# Epoch 16 Batch 1700 Loss 2.0505 Accuracy 0.5806
# Epoch 16 Batch 1750 Loss 2.0508 Accuracy 0.5806
# Epoch 16 Batch 1800 Loss 2.0508 Accuracy 0.5807
# Epoch 16 Batch 1850 Loss 2.0509 Accuracy 0.5806
# Epoch 16 Batch 1900 Loss 2.0506 Accuracy 0.5806
# Epoch 16 Batch 1950 Loss 2.0502 Accuracy 0.5807
# Epoch 16 Batch 2000 Loss 2.0508 Accuracy 0.5806
# Epoch 16 Batch 2050 Loss 2.0508 Accuracy 0.5806
# Epoch 16 Batch 2100 Loss 2.0507 Accuracy 0.5805
# Epoch 16 Batch 2150 Loss 2.0503 Accuracy 0.5806
# Epoch 16 Batch 2200 Loss 2.0501 Accuracy 0.5806
# Epoch 16 Batch 2250 Loss 2.0501 Accuracy 0.5806
# Epoch 16 Batch 2300 Loss 2.0498 Accuracy 0.5807
# Epoch 16 Batch 2350 Loss 2.0498 Accuracy 0.5807
# Epoch 16 Batch 2400 Loss 2.0496 Accuracy 0.5808
# Epoch 16 Batch 2450 Loss 2.0502 Accuracy 0.5807
# Epoch 16 Batch 2500 Loss 2.0507 Accuracy 0.5806
# Epoch 16 Batch 2550 Loss 2.0507 Accuracy 0.5806
# Epoch 16 Batch 2600 Loss 2.0511 Accuracy 0.5805
# Epoch 16 Loss 2.0513 Accuracy 0.5805
# Time taken for 1 epoch: 179.14831924438477 secs
#
# Epoch 17 Batch 0 Loss 2.0391 Accuracy 0.5833
# Epoch 17 Batch 50 Loss 2.0427 Accuracy 0.5800
# Epoch 17 Batch 100 Loss 2.0326 Accuracy 0.5823
# Epoch 17 Batch 150 Loss 2.0401 Accuracy 0.5814
# Epoch 17 Batch 200 Loss 2.0361 Accuracy 0.5818
# Epoch 17 Batch 250 Loss 2.0328 Accuracy 0.5822
# Epoch 17 Batch 300 Loss 2.0371 Accuracy 0.5818
# Epoch 17 Batch 350 Loss 2.0386 Accuracy 0.5816
# Epoch 17 Batch 400 Loss 2.0362 Accuracy 0.5821
# Epoch 17 Batch 450 Loss 2.0376 Accuracy 0.5820
# Epoch 17 Batch 500 Loss 2.0346 Accuracy 0.5823
# Epoch 17 Batch 550 Loss 2.0346 Accuracy 0.5823
# Epoch 17 Batch 600 Loss 2.0344 Accuracy 0.5824
# Epoch 17 Batch 650 Loss 2.0344 Accuracy 0.5822
# Epoch 17 Batch 700 Loss 2.0325 Accuracy 0.5826
# Epoch 17 Batch 750 Loss 2.0320 Accuracy 0.5826
# Epoch 17 Batch 800 Loss 2.0333 Accuracy 0.5826
# Epoch 17 Batch 850 Loss 2.0318 Accuracy 0.5829
# Epoch 17 Batch 900 Loss 2.0313 Accuracy 0.5830
# Epoch 17 Batch 950 Loss 2.0323 Accuracy 0.5828
# Epoch 17 Batch 1000 Loss 2.0326 Accuracy 0.5828
# Epoch 17 Batch 1050 Loss 2.0331 Accuracy 0.5829
# Epoch 17 Batch 1100 Loss 2.0335 Accuracy 0.5828
# Epoch 17 Batch 1150 Loss 2.0332 Accuracy 0.5828
# Epoch 17 Batch 1200 Loss 2.0333 Accuracy 0.5829
# Epoch 17 Batch 1250 Loss 2.0341 Accuracy 0.5827
# Epoch 17 Batch 1300 Loss 2.0336 Accuracy 0.5828
# Epoch 17 Batch 1350 Loss 2.0341 Accuracy 0.5827
# Epoch 17 Batch 1400 Loss 2.0349 Accuracy 0.5827
# Epoch 17 Batch 1450 Loss 2.0339 Accuracy 0.5828
# Epoch 17 Batch 1500 Loss 2.0336 Accuracy 0.5830
# Epoch 17 Batch 1550 Loss 2.0329 Accuracy 0.5831
# Epoch 17 Batch 1600 Loss 2.0323 Accuracy 0.5833
# Epoch 17 Batch 1650 Loss 2.0321 Accuracy 0.5833
# Epoch 17 Batch 1700 Loss 2.0315 Accuracy 0.5834
# Epoch 17 Batch 1750 Loss 2.0318 Accuracy 0.5834
# Epoch 17 Batch 1800 Loss 2.0314 Accuracy 0.5835
# Epoch 17 Batch 1850 Loss 2.0316 Accuracy 0.5834
# Epoch 17 Batch 1900 Loss 2.0315 Accuracy 0.5834
# Epoch 17 Batch 1950 Loss 2.0316 Accuracy 0.5834
# Epoch 17 Batch 2000 Loss 2.0317 Accuracy 0.5834
# Epoch 17 Batch 2050 Loss 2.0317 Accuracy 0.5834
# Epoch 17 Batch 2100 Loss 2.0316 Accuracy 0.5834
# Epoch 17 Batch 2150 Loss 2.0316 Accuracy 0.5835
# Epoch 17 Batch 2200 Loss 2.0319 Accuracy 0.5834
# Epoch 17 Batch 2250 Loss 2.0323 Accuracy 0.5833
# Epoch 17 Batch 2300 Loss 2.0324 Accuracy 0.5833
# Epoch 17 Batch 2350 Loss 2.0319 Accuracy 0.5834
# Epoch 17 Batch 2400 Loss 2.0322 Accuracy 0.5833
# Epoch 17 Batch 2450 Loss 2.0327 Accuracy 0.5833
# Epoch 17 Batch 2500 Loss 2.0330 Accuracy 0.5832
# Epoch 17 Batch 2550 Loss 2.0334 Accuracy 0.5831
# Epoch 17 Batch 2600 Loss 2.0331 Accuracy 0.5832
# Epoch 17 Loss 2.0329 Accuracy 0.5832
# Time taken for 1 epoch: 182.62904119491577 secs
#
# Epoch 18 Batch 0 Loss 1.9707 Accuracy 0.5921
# Epoch 18 Batch 50 Loss 2.0178 Accuracy 0.5841
# Epoch 18 Batch 100 Loss 2.0167 Accuracy 0.5844
# Epoch 18 Batch 150 Loss 2.0128 Accuracy 0.5856
# Epoch 18 Batch 200 Loss 2.0105 Accuracy 0.5861
# Epoch 18 Batch 250 Loss 2.0117 Accuracy 0.5858
# Epoch 18 Batch 300 Loss 2.0122 Accuracy 0.5861
# Epoch 18 Batch 350 Loss 2.0146 Accuracy 0.5858
# Epoch 18 Batch 400 Loss 2.0133 Accuracy 0.5859
# Epoch 18 Batch 450 Loss 2.0150 Accuracy 0.5855
# Epoch 18 Batch 500 Loss 2.0127 Accuracy 0.5860
# Epoch 18 Batch 550 Loss 2.0129 Accuracy 0.5861
# Epoch 18 Batch 600 Loss 2.0128 Accuracy 0.5861
# Epoch 18 Batch 650 Loss 2.0128 Accuracy 0.5860
# Epoch 18 Batch 700 Loss 2.0141 Accuracy 0.5858
# Epoch 18 Batch 750 Loss 2.0137 Accuracy 0.5858
# Epoch 18 Batch 800 Loss 2.0125 Accuracy 0.5859
# Epoch 18 Batch 850 Loss 2.0141 Accuracy 0.5856
# Epoch 18 Batch 900 Loss 2.0141 Accuracy 0.5857
# Epoch 18 Batch 950 Loss 2.0145 Accuracy 0.5856
# Epoch 18 Batch 1000 Loss 2.0153 Accuracy 0.5855
# Epoch 18 Batch 1050 Loss 2.0155 Accuracy 0.5857
# Epoch 18 Batch 1100 Loss 2.0169 Accuracy 0.5855
# Epoch 18 Batch 1150 Loss 2.0165 Accuracy 0.5856
# Epoch 18 Batch 1200 Loss 2.0154 Accuracy 0.5858
# Epoch 18 Batch 1250 Loss 2.0144 Accuracy 0.5859
# Epoch 18 Batch 1300 Loss 2.0154 Accuracy 0.5857
# Epoch 18 Batch 1350 Loss 2.0140 Accuracy 0.5859
# Epoch 18 Batch 1400 Loss 2.0136 Accuracy 0.5859
# Epoch 18 Batch 1450 Loss 2.0128 Accuracy 0.5860
# Epoch 18 Batch 1500 Loss 2.0134 Accuracy 0.5858
# Epoch 18 Batch 1550 Loss 2.0138 Accuracy 0.5857
# Epoch 18 Batch 1600 Loss 2.0132 Accuracy 0.5858
# Epoch 18 Batch 1650 Loss 2.0136 Accuracy 0.5858
# Epoch 18 Batch 1700 Loss 2.0140 Accuracy 0.5858
# Epoch 18 Batch 1750 Loss 2.0143 Accuracy 0.5858
# Epoch 18 Batch 1800 Loss 2.0143 Accuracy 0.5859
# Epoch 18 Batch 1850 Loss 2.0142 Accuracy 0.5859
# Epoch 18 Batch 1900 Loss 2.0145 Accuracy 0.5859
# Epoch 18 Batch 1950 Loss 2.0141 Accuracy 0.5859
# Epoch 18 Batch 2000 Loss 2.0146 Accuracy 0.5858
# Epoch 18 Batch 2050 Loss 2.0153 Accuracy 0.5858
# Epoch 18 Batch 2100 Loss 2.0155 Accuracy 0.5857
# Epoch 18 Batch 2150 Loss 2.0156 Accuracy 0.5857
# Epoch 18 Batch 2200 Loss 2.0159 Accuracy 0.5857
# Epoch 18 Batch 2250 Loss 2.0157 Accuracy 0.5858
# Epoch 18 Batch 2300 Loss 2.0163 Accuracy 0.5857
# Epoch 18 Batch 2350 Loss 2.0156 Accuracy 0.5858
# Epoch 18 Batch 2400 Loss 2.0155 Accuracy 0.5859
# Epoch 18 Batch 2450 Loss 2.0154 Accuracy 0.5859
# Epoch 18 Batch 2500 Loss 2.0154 Accuracy 0.5858
# Epoch 18 Batch 2550 Loss 2.0156 Accuracy 0.5858
# Epoch 18 Batch 2600 Loss 2.0160 Accuracy 0.5857
# Epoch 18 Loss 2.0161 Accuracy 0.5857
# Time taken for 1 epoch: 178.85234093666077 secs
#
# Epoch 19 Batch 0 Loss 2.0363 Accuracy 0.5894
# Epoch 19 Batch 50 Loss 2.0009 Accuracy 0.5865
# Epoch 19 Batch 100 Loss 1.9997 Accuracy 0.5866
# Epoch 19 Batch 150 Loss 1.9946 Accuracy 0.5876
# Epoch 19 Batch 200 Loss 1.9981 Accuracy 0.5874
# Epoch 19 Batch 250 Loss 1.9955 Accuracy 0.5876
# Epoch 19 Batch 300 Loss 1.9981 Accuracy 0.5875
# Epoch 19 Batch 350 Loss 1.9973 Accuracy 0.5875
# Epoch 19 Batch 400 Loss 1.9976 Accuracy 0.5876
# Epoch 19 Batch 450 Loss 1.9952 Accuracy 0.5881
# Epoch 19 Batch 500 Loss 1.9973 Accuracy 0.5878
# Epoch 19 Batch 550 Loss 1.9953 Accuracy 0.5882
# Epoch 19 Batch 600 Loss 1.9974 Accuracy 0.5880
# Epoch 19 Batch 650 Loss 1.9984 Accuracy 0.5878
# Epoch 19 Batch 700 Loss 1.9982 Accuracy 0.5879
# Epoch 19 Batch 750 Loss 1.9976 Accuracy 0.5880
# Epoch 19 Batch 800 Loss 1.9980 Accuracy 0.5880
# Epoch 19 Batch 850 Loss 1.9984 Accuracy 0.5880
# Epoch 19 Batch 900 Loss 1.9988 Accuracy 0.5880
# Epoch 19 Batch 950 Loss 1.9986 Accuracy 0.5880
# Epoch 19 Batch 1000 Loss 1.9982 Accuracy 0.5881
# Epoch 19 Batch 1050 Loss 1.9988 Accuracy 0.5881
# Epoch 19 Batch 1100 Loss 1.9990 Accuracy 0.5880
# Epoch 19 Batch 1150 Loss 1.9994 Accuracy 0.5880
# Epoch 19 Batch 1200 Loss 2.0002 Accuracy 0.5878
# Epoch 19 Batch 1250 Loss 1.9999 Accuracy 0.5879
# Epoch 19 Batch 1300 Loss 1.9996 Accuracy 0.5880
# Epoch 19 Batch 1350 Loss 1.9992 Accuracy 0.5882
# Epoch 19 Batch 1400 Loss 1.9991 Accuracy 0.5883
# ...
# Epoch 24 Batch 2500 Loss 1.9394 Accuracy 0.5970
# Epoch 24 Batch 2550 Loss 1.9397 Accuracy 0.5970
# Epoch 24 Batch 2600 Loss 1.9399 Accuracy 0.5969
# Epoch 24 Loss 1.9396 Accuracy 0.5970
# Time taken for 1 epoch: 183.2965841293335 secs
#
# Epoch 25 Batch 0 Loss 2.0448 Accuracy 0.5815
# Epoch 25 Batch 50 Loss 1.9120 Accuracy 0.6012
# Epoch 25 Batch 100 Loss 1.9222 Accuracy 0.5990
# Epoch 25 Batch 150 Loss 1.9265 Accuracy 0.5986
# Epoch 25 Batch 200 Loss 1.9248 Accuracy 0.5990
# Epoch 25 Batch 250 Loss 1.9259 Accuracy 0.5989
# Epoch 25 Batch 300 Loss 1.9253 Accuracy 0.5988
# Epoch 25 Batch 350 Loss 1.9218 Accuracy 0.5991
# Epoch 25 Batch 400 Loss 1.9190 Accuracy 0.5995
# Epoch 25 Batch 450 Loss 1.9199 Accuracy 0.5992
# Epoch 25 Batch 500 Loss 1.9220 Accuracy 0.5989
# Epoch 25 Batch 550 Loss 1.9226 Accuracy 0.5988
# Epoch 25 Batch 600 Loss 1.9213 Accuracy 0.5992
# Epoch 25 Batch 650 Loss 1.9253 Accuracy 0.5987
# Epoch 25 Batch 700 Loss 1.9248 Accuracy 0.5989
# Epoch 25 Batch 750 Loss 1.9248 Accuracy 0.5990
# Epoch 25 Batch 800 Loss 1.9243 Accuracy 0.5989
# Epoch 25 Batch 850 Loss 1.9238 Accuracy 0.5990
# Epoch 25 Batch 900 Loss 1.9236 Accuracy 0.5990
# Epoch 25 Batch 950 Loss 1.9252 Accuracy 0.5988
# Epoch 25 Batch 1000 Loss 1.9262 Accuracy 0.5987
# Epoch 25 Batch 1050 Loss 1.9264 Accuracy 0.5986
# Epoch 25 Batch 1100 Loss 1.9256 Accuracy 0.5988
# Epoch 25 Batch 1150 Loss 1.9255 Accuracy 0.5989
# Epoch 25 Batch 1200 Loss 1.9258 Accuracy 0.5988
# Epoch 25 Batch 1250 Loss 1.9258 Accuracy 0.5989
# Epoch 25 Batch 1300 Loss 1.9251 Accuracy 0.5990
# Epoch 25 Batch 1350 Loss 1.9247 Accuracy 0.5992
# Epoch 25 Batch 1400 Loss 1.9251 Accuracy 0.5991
# Epoch 25 Batch 1450 Loss 1.9256 Accuracy 0.5990
# Epoch 25 Batch 1500 Loss 1.9260 Accuracy 0.5989
# Epoch 25 Batch 1550 Loss 1.9255 Accuracy 0.5990
# Epoch 25 Batch 1600 Loss 1.9255 Accuracy 0.5990
# Epoch 25 Batch 1650 Loss 1.9263 Accuracy 0.5989
# Epoch 25 Batch 1700 Loss 1.9263 Accuracy 0.5990
# Epoch 25 Batch 1750 Loss 1.9271 Accuracy 0.5988
# Epoch 25 Batch 1800 Loss 1.9277 Accuracy 0.5987
# Epoch 25 Batch 1850 Loss 1.9277 Accuracy 0.5987
# Epoch 25 Batch 1900 Loss 1.9276 Accuracy 0.5987
# Epoch 25 Batch 1950 Loss 1.9273 Accuracy 0.5989
# Epoch 25 Batch 2000 Loss 1.9276 Accuracy 0.5988
# Epoch 25 Batch 2050 Loss 1.9276 Accuracy 0.5988
# Epoch 25 Batch 2100 Loss 1.9272 Accuracy 0.5989
# Epoch 25 Batch 2150 Loss 1.9265 Accuracy 0.5989
# Epoch 25 Batch 2200 Loss 1.9267 Accuracy 0.5989
# Epoch 25 Batch 2250 Loss 1.9269 Accuracy 0.5989
# Epoch 25 Batch 2300 Loss 1.9268 Accuracy 0.5989
# Epoch 25 Batch 2350 Loss 1.9275 Accuracy 0.5988
# Epoch 25 Batch 2400 Loss 1.9281 Accuracy 0.5987
# Epoch 25 Batch 2450 Loss 1.9278 Accuracy 0.5986
# Epoch 25 Batch 2500 Loss 1.9282 Accuracy 0.5986
# Epoch 25 Batch 2550 Loss 1.9288 Accuracy 0.5985
# Epoch 25 Batch 2600 Loss 1.9286 Accuracy 0.5986
# Saving checkpoint for epoch 25 at ./checkpoints/train/ckpt-5
# Epoch 25 Loss 1.9288 Accuracy 0.5985
# Time taken for 1 epoch: 179.3527159690857 secs
#
# Epoch 26 Batch 0 Loss 2.0577 Accuracy 0.5888
# Epoch 26 Batch 50 Loss 1.9211 Accuracy 0.6003
# Epoch 26 Batch 100 Loss 1.9126 Accuracy 0.6021
# Epoch 26 Batch 150 Loss 1.9115 Accuracy 0.6025
# Epoch 26 Batch 200 Loss 1.9076 Accuracy 0.6032
# Epoch 26 Batch 250 Loss 1.9095 Accuracy 0.6030
# Epoch 26 Batch 300 Loss 1.9049 Accuracy 0.6032
# Epoch 26 Batch 350 Loss 1.9094 Accuracy 0.6022
# Epoch 26 Batch 400 Loss 1.9110 Accuracy 0.6019
# Epoch 26 Batch 450 Loss 1.9119 Accuracy 0.6016
# Epoch 26 Batch 500 Loss 1.9121 Accuracy 0.6013
# Epoch 26 Batch 550 Loss 1.9126 Accuracy 0.6010
# Epoch 26 Batch 600 Loss 1.9133 Accuracy 0.6009
# Epoch 26 Batch 650 Loss 1.9145 Accuracy 0.6008
# Epoch 26 Batch 700 Loss 1.9148 Accuracy 0.6009
# Epoch 26 Batch 750 Loss 1.9148 Accuracy 0.6008
# Epoch 26 Batch 800 Loss 1.9156 Accuracy 0.6007
# Epoch 26 Batch 850 Loss 1.9164 Accuracy 0.6007
# Epoch 26 Batch 900 Loss 1.9174 Accuracy 0.6006
# Epoch 26 Batch 950 Loss 1.9176 Accuracy 0.6006
# Epoch 26 Batch 1000 Loss 1.9168 Accuracy 0.6007
# Epoch 26 Batch 1050 Loss 1.9170 Accuracy 0.6007
# Epoch 26 Batch 1100 Loss 1.9178 Accuracy 0.6005
# Epoch 26 Batch 1150 Loss 1.9172 Accuracy 0.6005
# Epoch 26 Batch 1200 Loss 1.9163 Accuracy 0.6007
# Epoch 26 Batch 1250 Loss 1.9165 Accuracy 0.6006
# Epoch 26 Batch 1300 Loss 1.9158 Accuracy 0.6008
# Epoch 26 Batch 1350 Loss 1.9153 Accuracy 0.6008
# Epoch 26 Batch 1400 Loss 1.9151 Accuracy 0.6010
# Epoch 26 Batch 1450 Loss 1.9155 Accuracy 0.6009
# Epoch 26 Batch 1500 Loss 1.9152 Accuracy 0.6010
# Epoch 26 Batch 1550 Loss 1.9157 Accuracy 0.6010
# Epoch 26 Batch 1600 Loss 1.9168 Accuracy 0.6008
# Epoch 26 Batch 1650 Loss 1.9170 Accuracy 0.6008
# Epoch 26 Batch 1700 Loss 1.9173 Accuracy 0.6008
# Epoch 26 Batch 1750 Loss 1.9172 Accuracy 0.6008
# Epoch 26 Batch 1800 Loss 1.9173 Accuracy 0.6008
# Epoch 26 Batch 1850 Loss 1.9177 Accuracy 0.6007
# Epoch 26 Batch 1900 Loss 1.9174 Accuracy 0.6007
# Epoch 26 Batch 1950 Loss 1.9172 Accuracy 0.6008
# Epoch 26 Batch 2000 Loss 1.9177 Accuracy 0.6007
# Epoch 26 Batch 2050 Loss 1.9176 Accuracy 0.6006
# Epoch 26 Batch 2100 Loss 1.9176 Accuracy 0.6006
# Epoch 26 Batch 2150 Loss 1.9179 Accuracy 0.6005
# Epoch 26 Batch 2200 Loss 1.9178 Accuracy 0.6005
# Epoch 26 Batch 2250 Loss 1.9181 Accuracy 0.6005
# Epoch 26 Batch 2300 Loss 1.9186 Accuracy 0.6004
# Epoch 26 Batch 2350 Loss 1.9188 Accuracy 0.6004
# Epoch 26 Batch 2400 Loss 1.9189 Accuracy 0.6004
# Epoch 26 Batch 2450 Loss 1.9192 Accuracy 0.6004
# Epoch 26 Batch 2500 Loss 1.9194 Accuracy 0.6003
# Epoch 26 Batch 2550 Loss 1.9196 Accuracy 0.6003
# Epoch 26 Batch 2600 Loss 1.9199 Accuracy 0.6002
# Epoch 26 Loss 1.9198 Accuracy 0.6002
# Time taken for 1 epoch: 181.87716937065125 secs
#
# Epoch 27 Batch 0 Loss 1.9963 Accuracy 0.5866
# Epoch 27 Batch 50 Loss 1.9019 Accuracy 0.6025
# Epoch 27 Batch 100 Loss 1.8992 Accuracy 0.6018
# Epoch 27 Batch 150 Loss 1.8992 Accuracy 0.6016
# Epoch 27 Batch 200 Loss 1.9038 Accuracy 0.6007
# Epoch 27 Batch 250 Loss 1.8988 Accuracy 0.6018
# Epoch 27 Batch 300 Loss 1.8984 Accuracy 0.6021
# Epoch 27 Batch 350 Loss 1.8995 Accuracy 0.6016
# Epoch 27 Batch 400 Loss 1.9009 Accuracy 0.6016
# Epoch 27 Batch 450 Loss 1.9013 Accuracy 0.6016
# Epoch 27 Batch 500 Loss 1.9016 Accuracy 0.6017
# Epoch 27 Batch 550 Loss 1.9049 Accuracy 0.6013
# Epoch 27 Batch 600 Loss 1.9061 Accuracy 0.6011
# Epoch 27 Batch 650 Loss 1.9067 Accuracy 0.6012
# Epoch 27 Batch 700 Loss 1.9053 Accuracy 0.6014
# Epoch 27 Batch 750 Loss 1.9061 Accuracy 0.6013
# Epoch 27 Batch 800 Loss 1.9065 Accuracy 0.6013
# Epoch 27 Batch 850 Loss 1.9076 Accuracy 0.6013
# Epoch 27 Batch 900 Loss 1.9090 Accuracy 0.6011
# Epoch 27 Batch 950 Loss 1.9089 Accuracy 0.6011
# Epoch 27 Batch 1000 Loss 1.9089 Accuracy 0.6011
# Epoch 27 Batch 1050 Loss 1.9092 Accuracy 0.6011
# Epoch 27 Batch 1100 Loss 1.9095 Accuracy 0.6011
# Epoch 27 Batch 1150 Loss 1.9097 Accuracy 0.6011
# Epoch 27 Batch 1200 Loss 1.9079 Accuracy 0.6015
# Epoch 27 Batch 1250 Loss 1.9080 Accuracy 0.6015
# Epoch 27 Batch 1300 Loss 1.9080 Accuracy 0.6015
# Epoch 27 Batch 1350 Loss 1.9085 Accuracy 0.6015
# Epoch 27 Batch 1400 Loss 1.9078 Accuracy 0.6015
# Epoch 27 Batch 1450 Loss 1.9083 Accuracy 0.6014
# Epoch 27 Batch 1500 Loss 1.9076 Accuracy 0.6016
# Epoch 27 Batch 1550 Loss 1.9076 Accuracy 0.6016
# Epoch 27 Batch 1600 Loss 1.9072 Accuracy 0.6016
# Epoch 27 Batch 1650 Loss 1.9076 Accuracy 0.6016
# Epoch 27 Batch 1700 Loss 1.9079 Accuracy 0.6015
# Epoch 27 Batch 1750 Loss 1.9081 Accuracy 0.6016
# Epoch 27 Batch 1800 Loss 1.9089 Accuracy 0.6014
# Epoch 27 Batch 1850 Loss 1.9097 Accuracy 0.6013
# Epoch 27 Batch 1900 Loss 1.9095 Accuracy 0.6014
# Epoch 27 Batch 1950 Loss 1.9093 Accuracy 0.6014
# Epoch 27 Batch 2000 Loss 1.9089 Accuracy 0.6015
# Epoch 27 Batch 2050 Loss 1.9089 Accuracy 0.6015
# Epoch 27 Batch 2100 Loss 1.9087 Accuracy 0.6016
# Epoch 27 Batch 2150 Loss 1.9089 Accuracy 0.6016
# Epoch 27 Batch 2200 Loss 1.9091 Accuracy 0.6015
# Epoch 27 Batch 2250 Loss 1.9104 Accuracy 0.6013
# Epoch 27 Batch 2300 Loss 1.9107 Accuracy 0.6013
# Epoch 27 Batch 2350 Loss 1.9107 Accuracy 0.6012
# Epoch 27 Batch 2400 Loss 1.9107 Accuracy 0.6012
# Epoch 27 Batch 2450 Loss 1.9112 Accuracy 0.6012
# Epoch 27 Batch 2500 Loss 1.9109 Accuracy 0.6012
# Epoch 27 Batch 2550 Loss 1.9111 Accuracy 0.6012
# Epoch 27 Batch 2600 Loss 1.9109 Accuracy 0.6012
# Epoch 27 Loss 1.9111 Accuracy 0.6012
# Time taken for 1 epoch: 179.77070140838623 secs
#
# Epoch 28 Batch 0 Loss 2.0600 Accuracy 0.5865
# Epoch 28 Batch 50 Loss 1.8766 Accuracy 0.6070
# Epoch 28 Batch 100 Loss 1.8988 Accuracy 0.6023
# Epoch 28 Batch 150 Loss 1.8956 Accuracy 0.6033
# Epoch 28 Batch 200 Loss 1.8980 Accuracy 0.6029
# Epoch 28 Batch 250 Loss 1.8985 Accuracy 0.6029
# Epoch 28 Batch 300 Loss 1.8970 Accuracy 0.6031
# Epoch 28 Batch 350 Loss 1.8975 Accuracy 0.6030
# Epoch 28 Batch 400 Loss 1.8972 Accuracy 0.6032
# Epoch 28 Batch 450 Loss 1.8984 Accuracy 0.6030
# Epoch 28 Batch 500 Loss 1.8986 Accuracy 0.6028
# Epoch 28 Batch 550 Loss 1.8972 Accuracy 0.6031
# Epoch 28 Batch 600 Loss 1.8979 Accuracy 0.6031
# Epoch 28 Batch 650 Loss 1.8967 Accuracy 0.6031
# Epoch 28 Batch 700 Loss 1.8955 Accuracy 0.6034
# Epoch 28 Batch 750 Loss 1.8951 Accuracy 0.6034
# Epoch 28 Batch 800 Loss 1.8947 Accuracy 0.6033
# Epoch 28 Batch 850 Loss 1.8951 Accuracy 0.6033
# Epoch 28 Batch 900 Loss 1.8948 Accuracy 0.6035
# Epoch 28 Batch 950 Loss 1.8945 Accuracy 0.6035
# Epoch 28 Batch 1000 Loss 1.8949 Accuracy 0.6036
# Epoch 28 Batch 1050 Loss 1.8949 Accuracy 0.6037
# Epoch 28 Batch 1100 Loss 1.8957 Accuracy 0.6035
# Epoch 28 Batch 1150 Loss 1.8965 Accuracy 0.6034
# Epoch 28 Batch 1200 Loss 1.8973 Accuracy 0.6033
# Epoch 28 Batch 1250 Loss 1.8982 Accuracy 0.6032
# Epoch 28 Batch 1300 Loss 1.8983 Accuracy 0.6032
# Epoch 28 Batch 1350 Loss 1.8984 Accuracy 0.6032
# Epoch 28 Batch 1400 Loss 1.8974 Accuracy 0.6034
# Epoch 28 Batch 1450 Loss 1.8980 Accuracy 0.6033
# Epoch 28 Batch 1500 Loss 1.8984 Accuracy 0.6032
# Epoch 28 Batch 1550 Loss 1.8983 Accuracy 0.6032
# Epoch 28 Batch 1600 Loss 1.8979 Accuracy 0.6033
# Epoch 28 Batch 1650 Loss 1.8984 Accuracy 0.6032
# Epoch 28 Batch 1700 Loss 1.8984 Accuracy 0.6032
# Epoch 28 Batch 1750 Loss 1.8982 Accuracy 0.6032
# Epoch 28 Batch 1800 Loss 1.8987 Accuracy 0.6031
# Epoch 28 Batch 1850 Loss 1.8990 Accuracy 0.6031
# Epoch 28 Batch 1900 Loss 1.9000 Accuracy 0.6030
# Epoch 28 Batch 1950 Loss 1.8997 Accuracy 0.6030
# Epoch 28 Batch 2000 Loss 1.8994 Accuracy 0.6031
# Epoch 28 Batch 2050 Loss 1.8998 Accuracy 0.6030
# Epoch 28 Batch 2100 Loss 1.9004 Accuracy 0.6030
# Epoch 28 Batch 2150 Loss 1.9001 Accuracy 0.6030
# Epoch 28 Batch 2200 Loss 1.9002 Accuracy 0.6030
# Epoch 28 Batch 2250 Loss 1.9004 Accuracy 0.6030
# Epoch 28 Batch 2300 Loss 1.9004 Accuracy 0.6029
# Epoch 28 Batch 2350 Loss 1.9008 Accuracy 0.6028
# Epoch 28 Batch 2400 Loss 1.9008 Accuracy 0.6029
# Epoch 28 Batch 2450 Loss 1.9007 Accuracy 0.6029
# Epoch 28 Batch 2500 Loss 1.9012 Accuracy 0.6028
# Epoch 28 Batch 2550 Loss 1.9015 Accuracy 0.6028
# Epoch 28 Batch 2600 Loss 1.9018 Accuracy 0.6027
# Epoch 28 Loss 1.9022 Accuracy 0.6027
# Time taken for 1 epoch: 181.09770965576172 secs
#
# Epoch 29 Batch 0 Loss 1.7710 Accuracy 0.6242
# Epoch 29 Batch 50 Loss 1.8835 Accuracy 0.6061
# Epoch 29 Batch 100 Loss 1.8848 Accuracy 0.6055
# Epoch 29 Batch 150 Loss 1.8848 Accuracy 0.6054
# Epoch 29 Batch 200 Loss 1.8797 Accuracy 0.6060
# Epoch 29 Batch 250 Loss 1.8823 Accuracy 0.6053
# Epoch 29 Batch 300 Loss 1.8793 Accuracy 0.6058
# Epoch 29 Batch 350 Loss 1.8825 Accuracy 0.6051
# Epoch 29 Batch 400 Loss 1.8863 Accuracy 0.6046
# Epoch 29 Batch 450 Loss 1.8870 Accuracy 0.6044
# Epoch 29 Batch 500 Loss 1.8882 Accuracy 0.6043
# Epoch 29 Batch 550 Loss 1.8893 Accuracy 0.6042
# Epoch 29 Batch 600 Loss 1.8909 Accuracy 0.6041
# Epoch 29 Batch 650 Loss 1.8904 Accuracy 0.6043
# Epoch 29 Batch 700 Loss 1.8911 Accuracy 0.6042
# Epoch 29 Batch 750 Loss 1.8913 Accuracy 0.6041
# Epoch 29 Batch 800 Loss 1.8921 Accuracy 0.6041
# Epoch 29 Batch 850 Loss 1.8922 Accuracy 0.6041
# Epoch 29 Batch 900 Loss 1.8915 Accuracy 0.6042
# Epoch 29 Batch 950 Loss 1.8923 Accuracy 0.6041
# Epoch 29 Batch 1000 Loss 1.8926 Accuracy 0.6041
# Epoch 29 Batch 1050 Loss 1.8935 Accuracy 0.6038
# Epoch 29 Batch 1100 Loss 1.8943 Accuracy 0.6037
# Epoch 29 Batch 1150 Loss 1.8934 Accuracy 0.6039
# Epoch 29 Batch 1200 Loss 1.8937 Accuracy 0.6038
# Epoch 29 Batch 1250 Loss 1.8934 Accuracy 0.6038
# Epoch 29 Batch 1300 Loss 1.8936 Accuracy 0.6038
# Epoch 29 Batch 1350 Loss 1.8931 Accuracy 0.6040
# Epoch 29 Batch 1400 Loss 1.8930 Accuracy 0.6040
# Epoch 29 Batch 1450 Loss 1.8927 Accuracy 0.6041
# Epoch 29 Batch 1500 Loss 1.8935 Accuracy 0.6039
# Epoch 29 Batch 1550 Loss 1.8928 Accuracy 0.6041
# Epoch 29 Batch 1600 Loss 1.8925 Accuracy 0.6041
# Epoch 29 Batch 1650 Loss 1.8927 Accuracy 0.6041
# Epoch 29 Batch 1700 Loss 1.8928 Accuracy 0.6041
# Epoch 29 Batch 1750 Loss 1.8929 Accuracy 0.6041
# Epoch 29 Batch 1800 Loss 1.8931 Accuracy 0.6040
# Epoch 29 Batch 1850 Loss 1.8928 Accuracy 0.6040
# Epoch 29 Batch 1900 Loss 1.8925 Accuracy 0.6041
# Epoch 29 Batch 1950 Loss 1.8920 Accuracy 0.6042
# Epoch 29 Batch 2000 Loss 1.8922 Accuracy 0.6042
# Epoch 29 Batch 2050 Loss 1.8932 Accuracy 0.6041
# Epoch 29 Batch 2100 Loss 1.8938 Accuracy 0.6039
# Epoch 29 Batch 2150 Loss 1.8940 Accuracy 0.6039
# Epoch 29 Batch 2200 Loss 1.8944 Accuracy 0.6038
# Epoch 29 Batch 2250 Loss 1.8944 Accuracy 0.6039
# Epoch 29 Batch 2300 Loss 1.8946 Accuracy 0.6038
# Epoch 29 Batch 2350 Loss 1.8950 Accuracy 0.6037
# Epoch 29 Batch 2400 Loss 1.8949 Accuracy 0.6037
# Epoch 29 Batch 2450 Loss 1.8949 Accuracy 0.6038
# Epoch 29 Batch 2500 Loss 1.8949 Accuracy 0.6038
# Epoch 29 Batch 2550 Loss 1.8948 Accuracy 0.6037
# Epoch 29 Batch 2600 Loss 1.8951 Accuracy 0.6037
# Epoch 29 Loss 1.8948 Accuracy 0.6037
# Time taken for 1 epoch: 179.6663258075714 secs
#
# Epoch 30 Batch 0 Loss 1.6819 Accuracy 0.6422
# Epoch 30 Batch 50 Loss 1.8871 Accuracy 0.6051
# Epoch 30 Batch 100 Loss 1.8716 Accuracy 0.6081
# Epoch 30 Batch 150 Loss 1.8756 Accuracy 0.6068
# Epoch 30 Batch 200 Loss 1.8829 Accuracy 0.6056
# Epoch 30 Batch 250 Loss 1.8803 Accuracy 0.6061
# Epoch 30 Batch 300 Loss 1.8769 Accuracy 0.6064
# Epoch 30 Batch 350 Loss 1.8759 Accuracy 0.6064
# Epoch 30 Batch 400 Loss 1.8802 Accuracy 0.6059
# Epoch 30 Batch 450 Loss 1.8786 Accuracy 0.6061
# Epoch 30 Batch 500 Loss 1.8761 Accuracy 0.6064
# Epoch 30 Batch 550 Loss 1.8769 Accuracy 0.6062
# Epoch 30 Batch 600 Loss 1.8777 Accuracy 0.6061
# Epoch 30 Batch 650 Loss 1.8790 Accuracy 0.6059
# Epoch 30 Batch 700 Loss 1.8803 Accuracy 0.6058
# Epoch 30 Batch 750 Loss 1.8815 Accuracy 0.6056
# Epoch 30 Batch 800 Loss 1.8826 Accuracy 0.6054
# Epoch 30 Batch 850 Loss 1.8827 Accuracy 0.6053
# Epoch 30 Batch 900 Loss 1.8849 Accuracy 0.6050
# Epoch 30 Batch 950 Loss 1.8848 Accuracy 0.6050
# Epoch 30 Batch 1000 Loss 1.8849 Accuracy 0.6052
# Epoch 30 Batch 1050 Loss 1.8850 Accuracy 0.6050
# Epoch 30 Batch 1100 Loss 1.8846 Accuracy 0.6052
# Epoch 30 Batch 1150 Loss 1.8855 Accuracy 0.6050
# Epoch 30 Batch 1200 Loss 1.8856 Accuracy 0.6050
# Epoch 30 Batch 1250 Loss 1.8850 Accuracy 0.6051
# Epoch 30 Batch 1300 Loss 1.8842 Accuracy 0.6052
# Epoch 30 Batch 1350 Loss 1.8839 Accuracy 0.6054
# Epoch 30 Batch 1400 Loss 1.8844 Accuracy 0.6053
# Epoch 30 Batch 1450 Loss 1.8832 Accuracy 0.6055
# Epoch 30 Batch 1500 Loss 1.8841 Accuracy 0.6053
# Epoch 30 Batch 1550 Loss 1.8843 Accuracy 0.6053
# Epoch 30 Batch 1600 Loss 1.8846 Accuracy 0.6053
# Epoch 30 Batch 1650 Loss 1.8843 Accuracy 0.6053
# Epoch 30 Batch 1700 Loss 1.8842 Accuracy 0.6053
# Epoch 30 Batch 1750 Loss 1.8845 Accuracy 0.6053
# Epoch 30 Batch 1800 Loss 1.8844 Accuracy 0.6053
# Epoch 30 Batch 1850 Loss 1.8847 Accuracy 0.6052
# Epoch 30 Batch 1900 Loss 1.8852 Accuracy 0.6051
# Epoch 30 Batch 1950 Loss 1.8854 Accuracy 0.6050
# Epoch 30 Batch 2000 Loss 1.8851 Accuracy 0.6051
# Epoch 30 Batch 2050 Loss 1.8850 Accuracy 0.6051
# Epoch 30 Batch 2100 Loss 1.8852 Accuracy 0.6051
# Epoch 30 Batch 2150 Loss 1.8857 Accuracy 0.6050
# Epoch 30 Batch 2200 Loss 1.8859 Accuracy 0.6051
# Epoch 30 Batch 2250 Loss 1.8859 Accuracy 0.6051
# Epoch 30 Batch 2300 Loss 1.8863 Accuracy 0.6051
# Epoch 30 Batch 2350 Loss 1.8868 Accuracy 0.6050
# Epoch 30 Batch 2400 Loss 1.8867 Accuracy 0.6050
# Epoch 30 Batch 2450 Loss 1.8866 Accuracy 0.6050
# Epoch 30 Batch 2500 Loss 1.8869 Accuracy 0.6050
# Epoch 30 Batch 2550 Loss 1.8870 Accuracy 0.6050
# Epoch 30 Batch 2600 Loss 1.8870 Accuracy 0.6050
# Saving checkpoint for epoch 30 at ./checkpoints/train/ckpt-6
# Epoch 30 Loss 1.8872 Accuracy 0.6049
# Time taken for 1 epoch: 183.68252110481262 secs

# %%
def evaluate(inp_sentence):
  start_token = [tokenizer_ru.vocab_size]
  end_token = [tokenizer_ru.vocab_size + 1]
  
  # inp sentence is portuguese, hence adding the start and end token
  inp_sentence = start_token + tokenizer_ru.encode(inp_sentence) + end_token
  encoder_input = tf.expand_dims(inp_sentence, 0)
  
  # as the target is english, the first word to the transformer should be the
  # english start token.
  decoder_input = [tokenizer_en.vocab_size]
  output = tf.expand_dims(decoder_input, 0)
    
  for i in range(MAX_LENGTH):
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(
        encoder_input, output)
  
    # predictions.shape == (batch_size, seq_len, vocab_size)
    predictions, attention_weights = transformer(encoder_input, 
                                                 output,
                                                 False,
                                                 enc_padding_mask,
                                                 combined_mask,
                                                 dec_padding_mask)
    
    # select the last word from the seq_len dimension
    predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)
    
    # return the result if the predicted_id is equal to the end token
    if predicted_id == tokenizer_en.vocab_size+1:
      return tf.squeeze(output, axis=0), attention_weights
    
    # concatentate the predicted_id to the output which is given to the decoder
    # as its input.
    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0), attention_weights

# %%
def plot_attention_weights(attention, sentence, result, layer):
  fig = plt.figure(figsize=(16, 8))
  
  sentence = tokenizer_ru.encode(sentence)
  
  attention = tf.squeeze(attention[layer], axis=0)
  
  for head in range(attention.shape[0]):
    ax = fig.add_subplot(2, 4, head+1)
    
    # plot the attention weights
    ax.matshow(attention[head][:-1, :], cmap='viridis')

    fontdict = {'fontsize': 10}
    
    ax.set_xticks(range(len(sentence)+2))
    ax.set_yticks(range(len(result)))
    
    ax.set_ylim(len(result)-1.5, -0.5)
        
    ax.set_xticklabels(
        ['<start>']+[tokenizer_ru.decode([i]) for i in sentence]+['<end>'], 
        fontdict=fontdict, rotation=90)
    
    ax.set_yticklabels([tokenizer_en.decode([i]) for i in result 
                        if i < tokenizer_en.vocab_size], 
                       fontdict=fontdict)
    
    ax.set_xlabel('Head {}'.format(head+1))
  
  plt.tight_layout()
  plt.show()

# %%
def translate(sentence, plot='decoder_layer4_block2'):
  result, attention_weights = evaluate(sentence)
  # print(attention_weights)
  
  predicted_sentence = tokenizer_en.decode([i for i in result 
                                            if i < tokenizer_en.vocab_size])  

  print('Input: {}'.format(sentence))
  print('Predicted translation: {}'.format(predicted_sentence))
  
  if plot:
    plot_attention_weights(attention_weights, sentence, result, plot)

# %%
translate(u'доброе утро')
# Out:
# Input: доброе утро
# Predicted translation: good morning .
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-9f4f38500aba> in <cell line: 1>()
# ----> 1 translate(u'доброе утро')
#
# <ipython-input-53-e48162765f0c> in translate(sentence, plot)
#      10
#      11   if plot:
# ---> 12     plot_attention_weights(attention_weights, sentence, result, plot)
#
# <ipython-input-52-e8a0b767726b> in plot_attention_weights(attention, sentence, result, layer)
#      23         fontdict=fontdict, rotation=90)
#      24
# ---> 25     ax.set_yticklabels([tokenizer_en.decode([i]) for i in result
#      26                         if i < tokenizer_en.vocab_size],
#      27                        fontdict=fontdict)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (3).

# %%
translate(u'она ушла домой')
# Out:
# Input: она ушла домой
# Predicted translation: she walked home home .
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-8b872f213a12> in <cell line: 1>()
# ----> 1 translate(u'она ушла домой')
#
# <ipython-input-53-e48162765f0c> in translate(sentence, plot)
#      10
#      11   if plot:
# ---> 12     plot_attention_weights(attention_weights, sentence, result, plot)
#
# <ipython-input-52-e8a0b767726b> in plot_attention_weights(attention, sentence, result, layer)
#      23         fontdict=fontdict, rotation=90)
#      24
# ---> 25     ax.set_yticklabels([tokenizer_en.decode([i]) for i in result
#      26                         if i < tokenizer_en.vocab_size],
#      27                        fontdict=fontdict)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (6), usually from a call to set_ticks, does not match the number of labels (5).
