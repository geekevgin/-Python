# %% [markdown]
# <a href="https://colab.research.google.com/github/geekevgin/-Python/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A Safety and Immune Response Study of 2 Experimental HIV Vaccines.
#
# Исследование содержит 3 фазы, доступен план статистического анализа(SAP), протокол и результаты.
#
# 252 человека участвовали в исследовании. В процессе были поставлены следующие задачи:
#
# - Безопасна ли вакцина для человека?
# - Может ли человек переносить вакцину без дискомфорта?
# - Как иммуная система отвечает на вакцину?
#
# В исследовании использовались 2 разные вакцины ALVAC-HIV (vCP2438) и  gp120/MF59. Это эксперементальные вакцины и исследователи не обладают информацией о безопасности вакцины или способности предотвращать заражение ВИЧ-инфекцией.

# %% [markdown]
# 1. Посмотреть как устроен документ
#
# 4 обширных раздела:
# 1. Study details, детали исследования
# 2. Table view (данные исследованя/основные положения в таблийах)
# 3. Results Overview
# 4. Record history
#
# Первая часть представлена кратким обзором исследования, местом проведения исследования, критерии отбора участников исследования, какие данные в процессе ислледрвания будут изучаться и измеряться, сотрудничество, хронография исследования,
#
# Вторая часть включает даты записей исследования( когда были представлены, опубликованы) и итоговые показатели, которые измеряли.
#
# Третья часть представлена результатами.

# %% [markdown]
# 2. Найти описание дизайна исследования - рандомизированное или нет, какое заслепление, какое показание, какие группы сравнения, сколько человек в каждой группе сравнения, есть ли стратификация и по каким признакам.
#
# Данное исследование:
# - рандомизированноедве
# - параллельные группы:
#     - 1я группа(вакцина) получала вакцину  ALVAC-HIV в начале исследования и черезе 1 месяц и  ALVAC-HIV+ bivalent subtype C на 3й, 6й, 12й месяц исследования,  210 человек.
#     - 2я группа(плацебо) 1я группа получала вакцину  ALVAC-HIV в начале исследования и черезе 1 месяц и  ALVAC-HIV+ placebo на 3й, 6й, 12й месяц исследования, 42 человека.
# - заслепление тройное
# - основное показание - профилактика заболеваемости
# - всего в исследовании приняло участие 252 человека
# - не нашла данных за стратификацию

# %% [markdown]
# 3. Найти раздел с конечными точками, разобрать каждую точку и определить ее тип - первичная/вторичная, клиническая/суррогатная
#
# Первичная точка профилактика заболевания вакцинацией.
# Вторичная точка безопасность вакцины, ответ имунной системы
#
# Клиническая точки:  боль,эритема, уплотнение в месте инъекции, HIV-1-specific IgG,  gp120, 	CD4+ T Cell Responses
#
# Суррогатные точки: усталость, миалгия, головная боль, рвота, артралгия, температура, клинический анализ крови, биохимический аналих крови

# %% [markdown]
# 4. Посмотреть результаты на сайте на странице исследования, определить было исследование успешным или нет.
#
# -Срванение событий связывния IgG c gp120, содержащийся в вакцине не показало статистически значимых результатов.
#
# - Сравнение уровня IgG, связаного с gp120, содержащегося в вакцине показало статистически значимый результаи (P-Value	<.0001)
#
# - Сравнение событий клеточного ответа (СD4+) к белкам вируса ВИЧ-инфекции не показало статистически значимых результатов (P-Value		0.1435)
#
# -  Сравнение уровня СD4+ к белкам вируса ВИЧ-инфекции не показало статистически значимых результатов тоже статистически незначимо (P-Value	0.9661)
#
# Чтобы вакцина была успешной необходима выроботка АТ и клеточного иммунитета.
# Как видим, стимулировать клеточный иммунет вакциной не получилось.
